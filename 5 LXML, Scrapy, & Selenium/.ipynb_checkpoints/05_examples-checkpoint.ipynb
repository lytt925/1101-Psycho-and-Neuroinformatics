# %% [markdown]
# # Psychoinformatics - Week 5 (Examples)
# by Tsung-Ren (Tren) Huang (trhuang@g.ntu.edu.tw)

# %% [markdown]
# ## 1 HTML & CSS

# %% [markdown]
# ### 1.1 Getting pages from PTT

# %%
import urllib.request

# %% [markdown]
# #### 1.1.1 List of articles

# %%
u='http://www.ptt.cc/bbs/Boy-Girl/'
r=urllib.request.Request(u,headers={'User-Agent':''})
data=urllib.request.urlopen(r).read()
print(data.decode('utf-8'))
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Boy-Girl 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Boy-Girl/index.html"><span class="board-label">看板 </span>Boy-Girl</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
#
# <div id="main-container">
# 	<div id="action-bar-container">
# 		<div class="action-bar">
# 			<div class="btn-group btn-group-dir">
# 				<a class="btn selected" href="/bbs/Boy-Girl/index.html">看板</a>
# 				<a class="btn" href="/man/Boy-Girl/index.html">精華區</a>
# 			</div>
# 			<div class="btn-group btn-group-paging">
# 				<a class="btn wide" href="/bbs/Boy-Girl/index1.html">最舊</a>
# 				<a class="btn wide" href="/bbs/Boy-Girl/index5521.html">&lsaquo; 上頁</a>
# 				<a class="btn wide disabled">下頁 &rsaquo;</a>
# 				<a class="btn wide" href="/bbs/Boy-Girl/index.html">最新</a>
# 			</div>
# 		</div>
# 	</div>
#
# 	<div class="r-list-container action-bar-margin bbs-screen">
# 		<div class="search-bar">
# 			<form type="get" action="search" id="search-bar">
# 				<input class="query" type="text" name="q" value="" placeholder="搜尋文章&#x22ef;">
# 			</form>
# 		</div>
#
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Boy-Girl/M.1634962743.A.ADC.html">Re: [討論] 說謊 該如何睡得安穩</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">Latte5566</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Boy-Girl/search?q=thread%3A%5B%E8%A8%8E%E8%AB%96%5D&#43;%E8%AA%AA%E8%AC%8A&#43;%E8%A9%B2%E5%A6%82%E4%BD%95%E7%9D%A1%E5%BE%97%E5%AE%89%E7%A9%A9">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Boy-Girl/search?q=author%3ALatte5566">搜尋看板內 Latte5566 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">10/23</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">5</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Boy-Girl/M.1634965200.A.4A6.html">[討論] 有斷絕關係切結書?</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">kaki1231</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Boy-Girl/search?q=thread%3A%5B%E8%A8%8E%E8%AB%96%5D&#43;%E6%9C%89%E6%96%B7%E7%B5%95%E9%97%9C%E4%BF%82%E5%88%87%E7%B5%90%E6%9B%B8%3F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Boy-Girl/search?q=author%3Akaki1231">搜尋看板內 kaki1231 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">10/23</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Boy-Girl/M.1634965863.A.3B3.html">Re: [討論] 說謊 該如何睡得安穩</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">skinjazz</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Boy-Girl/search?q=thread%3A%5B%E8%A8%8E%E8%AB%96%5D&#43;%E8%AA%AA%E8%AC%8A&#43;%E8%A9%B2%E5%A6%82%E4%BD%95%E7%9D%A1%E5%BE%97%E5%AE%89%E7%A9%A9">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Boy-Girl/search?q=author%3Askinjazz">搜尋看板內 skinjazz 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">10/23</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">4</span></div>
# 			<div class="title">
#
# 				(本文已被刪除) [osmanthusjo]
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">-</div>
# 				<div class="article-menu">
#
# 				</div>
# 				<div class="date">10/23</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">18</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Boy-Girl/M.1634967945.A.50E.html">[討論] 對心靈雞湯的駁斥謬誤</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">rabinson</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Boy-Girl/search?q=thread%3A%5B%E8%A8%8E%E8%AB%96%5D&#43;%E5%B0%8D%E5%BF%83%E9%9D%88%E9%9B%9E%E6%B9%AF%E7%9A%84%E9%A7%81%E6%96%A5%E8%AC%AC%E8%AA%A4">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Boy-Girl/search?q=author%3Arabinson">搜尋看板內 rabinson 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">10/23</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">1</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Boy-Girl/M.1634970651.A.FBA.html">Re: [討論] 如何安撫女友對房貸的恐懼?</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">pauljet</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Boy-Girl/search?q=thread%3A%5B%E8%A8%8E%E8%AB%96%5D&#43;%E5%A6%82%E4%BD%95%E5%AE%89%E6%92%AB%E5%A5%B3%E5%8F%8B%E5%B0%8D%E6%88%BF%E8%B2%B8%E7%9A%84%E6%81%90%E6%87%BC%3F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Boy-Girl/search?q
的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 9/08</div>
# 				<div class="mark">M</div>
# 			</div>
# 		</div>
#
#
#
# 	</div>
#
#
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
#
#     </body>
# </html>

# %% [markdown]
# #### 1.1.2 A specific article

# %%
u='https://www.ptt.cc/bbs/Boy-Girl/M.1394964006.A.850.html'
r=urllib.request.Request(u,headers={'User-Agent':''})
data=urllib.request.urlopen(r).read()
print(data.decode('utf-8'))
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>Re: [心情] 我要怎麼原諒那個人 - 看板 Boy-Girl - 批踢踢實業坊</title>
# <meta name="robots" content="all">
# <meta name="keywords" content="Ptt BBS 批踢踢">
# <meta name="description" content="想一想，事情最壞可以多壞？假如那個人成為你的老公，你被內射了幾次，小孩生下後
# 你不清楚他失業了沒，反正他不拿錢回家，外面欠一屁股債，還跟外遇對象也生了三個
# 外遇對象是越南小吃店的員工，被警察抓到後登上社會版頭條，結果說去驗DNA發現
# 還不是你老公的種，所以小孩要被遣返，有人跳出來說你應該扶養這三個小孩
# 記者打電話給你，網友肉搜你，名嘴討論你，債主騷擾你
# ">
# <meta property="og:site_name" content="Ptt 批踢踢實業坊">
# <meta property="og:title" content="Re: [心情] 我要怎麼原諒那個人">
# <meta property="og:description" content="想一想，事情最壞可以多壞？假如那個人成為你的老公，你被內射了幾次，小孩生下後
# 你不清楚他失業了沒，反正他不拿錢回家，外面欠一屁股債，還跟外遇對象也生了三個
# 外遇對象是越南小吃店的員工，被警察抓到後登上社會版頭條，結果說去驗DNA發現
# 還不是你老公的種，所以小孩要被遣返，有人跳出來說你應該扶養這三個小孩
# 記者打電話給你，網友肉搜你，名嘴討論你，債主騷擾你
# ">
# <link rel="canonical" href="https://www.ptt.cc/bbs/Boy-Girl/M.1394964006.A.850.html">
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Boy-Girl/index.html"><span class="board-label">看板 </span>Boy-Girl</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
# <div id="navigation-container">
# 	<div id="navigation" class="bbs-content">
# 		<a class="board" href="/bbs/Boy-Girl/index.html">返回看板</a>
# 		<div class="bar"></div>
# 	</div>
# </div>
# <div id="main-container">
#     <div id="main-content" class="bbs-screen bbs-content"><div class="article-metaline"><span class="article-meta-tag">作者</span><span class="article-meta-value">wbson (Simple Power)</span></div><div class="article-metaline-right"><span class="article-meta-tag">站內</span><span class="article-meta-value">Boy-Girl</span></div><div class="article-metaline"><span class="article-meta-tag">標題</span><span class="article-meta-value">Re: [心情] 我要怎麼原諒那個人</span></div><div class="article-metaline"><span class="article-meta-tag">時間</span><span class="article-meta-value">Sun Mar 16 18:00:03 2014</span></div>
# 想一想，事情最壞可以多壞？假如那個人成為你的老公，你被內射了幾次，小孩生下後
#
# 你不清楚他失業了沒，反正他不拿錢回家，外面欠一屁股債，還跟外遇對象也生了三個
#
# 外遇對象是越南小吃店的員工，被警察抓到後登上社會版頭條，結果說去驗DNA發現
#
# 還不是你老公的種，所以小孩要被遣返，有人跳出來說你應該扶養這三個小孩
#
# 記者打電話給你，網友肉搜你，名嘴討論你，債主騷擾你
#
#
# 又或者看一下三立或民視的鄉土劇，它們節目收視率好不是沒有原因的，
#
# 因為大多數人的生活中總是可以找到跟劇中情節類似的故事。
#
#
# 這個世界可以很殘忍可可怕的，在那麼多套杯具裡面，你選一個用了八九年之久，
#
# 現在它破了，你把它丟掉正好。有人會為了自己丟掉的垃圾被資源回收婆婆撿回家去用
#
# 而傷心落淚嗎？
#
#
#
# <span class="f2">※ 引述《Qion (珍惜)》之銘言：
# </span><span class="f6">: 在一個人身上花了八九年的時間
# </span><span class="f6">: 因為既有的問題無法解決 關於結婚也無法達成共識
# </span><span class="f6">: 我們分手了
# </span><span class="f6">: 他不到三個月就交了新的 是以前就常一起出國玩
# </span><span class="f6">: 會去接送的人 為什麼是她。。。
# </span><span class="f6">: 現在聽說要結婚(一年多了)
# </span><span class="f6">: 怎麼辦呢我毫無意識的眼淚掉了滿地
# </span><span class="f6">: 這個爛人
# </span><span class="f6">: 共同的朋友不敢告訴我但還是被我知道了
# </span><span class="f6">: 這個人我無法原諒
# </span><span class="f6">: 可是不原諒要怎麼辦 放過自己否則要怎麼過日子?
# </span><span class="f6">: 好想選擇一個容易的 逃避一切痛苦的方法
# </span><span class="f6">: 可是我能嗎?
# </span><span class="f6">: 我這麼努力的 好好活著 重新建立我的生活
# </span><span class="f6">: 一直對抗著不被珍惜的恐懼 被背叛被丟棄的痛苦
# </span><span class="f6">: 可是我的堅強還是被打垮
# </span><span class="f6">: 真的很恨他 如果可以不遇見 該有多好
# </span>
# --
# <span class="f2">※ 發信站: 批踢踢實業坊(ptt.cc)
# </span>◆ From: 172.2.206.224
# <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">winds19903</span><span class="f3 push-content">:推最後一段</span><span class="push-ipdatetime"> 03/16 19:25
# </span></div></div>
#
#     <div id="article-polling" data-pollurl="/poll/Boy-Girl/M.1394964006.A.850.html?cacheKey=2148-98589289&amp;offset=1501&amp;offset-sig=524863f83251ebdca4f0be5e2b26cbe7059a9c99" data-longpollurl="/v1/longpoll?id=76cff78a4ab7fe3c25ed6ed834e5f07b4ccd1909" data-offset="1501"></div>
#
#
#
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
#
#     </body>
# </html>

# %%
u='https://www.ptt.cc/bbs/Boy-Girl/M.1394964006.A.850.html'
r=urllib.request.Request(u,headers={'User-Agent':''})
data=urllib.request.urlopen(r)
print(data.getheaders())
# Out:
# [('Date', 'Sat, 23 Oct 2021 10:46:05 GMT'), ('Content-Type', 'text/html; charset=utf-8'), ('Transfer-Encoding', 'chunked'), ('Connection', 'close'), ('alternate-protocol', '443:npn-spdy/3'), ('strict-transport-security', 'max-age=0'), ('CF-Cache-Status', 'DYNAMIC'), ('Expect-CT', 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"'), ('Set-Cookie', '__cf_bm=a5cR8ZOgdlhSyW9jbRCv7OUWQbBUriIzYcsuAZXbg30-1634985965-0-AWTvGNzgniuL5s2mxAm5oln7QF76NhT7+XsdaygdyKZ4sYVlQ2LZvQT37H1mxShxFGYLtPBYNmGdpQOpyS1/Pyw=; path=/; expires=Sat, 23-Oct-21 11:16:05 GMT; domain=.ptt.cc; HttpOnly; Secure; SameSite=None'), ('Report-To', '{"endpoints":[{"url":"https:\\/\\/a.nel.cloudflare.com\\/report\\/v3?s=i7v%2BtoH6tytbBMAQE0oHROXVIzbebI%2BCzh0zkps1%2B4%2FUL8qvuzdIwZoHds95PZii8RnqkiaurB6Bo3k2W83waSlgCyAgrSxns8WP3h4AeuO0Btxj3XppCsTWf3it"}],"group":"cf-nel","max_age":604800}'), ('NEL', '{"success_fraction":0,"report_to":"cf-nel","max_age":604800}'), ('X-Content-Type-Options', 'nosniff'), ('Server', 'cloudflare'), ('CF-RAY', '6a2a612b3cc66baa-SIN'), ('alt-svc', 'h3=":443"; ma=86400, h3-29=":443"; ma=86400, h3-28=":443"; ma=86400, h3-27=":443"; ma=86400')]

# %% [markdown]
# ### 1.2 Basic HTML

# %% [markdown]
# <h1>標1</h1><hr> <h2>標2</hr> <a href="http://ptt.cc">連接</a>
# <br><br><br><br>
# <hr><hr>
# 這樣<br>可以斷行 <img src="http://bit.ly/1p2za46" width=50%>
# <center>這樣可以置中和<font color=red>換色</font></center>
# <ul>
# <li><b>粗體</b></li>
# <li><i>斜體</i></li>    <li><u>底線</u></li>
# </ul>
# <table border=1>
# <tr><td>11</td>    <td>12</td></tr>
# <tr><td>21</td>                                   <td>22</td></tr>
# </table>

# %% [markdown]
# ### 1.3 Basic CSS

# %% [markdown]
# #### 1.3.1 CSS not working in Jypyter Notebook

# %% [markdown]
# <style>
# body {color:white; background-color:black;}
# h1 {color:red; font-size:20pt}
# .yy {color:yellow}
# span#gg {color:green}
# div#bb {color:blue}
# </style>
# <h1>Hi!</h1>
# This is <span class=yy>test1</span><hr>
# This is <div class=yy>test2</div><hr>
# This is <span id=gg>test3</span><hr>
# This is <div id=gg>test4</div><hr>
# This is <div id=bb>test5</div><hr>

# %% [markdown]
# #### 1.3.2 CSS working in regular webpages

# %%
from IPython.display import HTML
HTML('<iframe width="560" height="315" src="http://hpc.psy.ntu.edu.tw/info/05/css.html" frameborder="0" allow="autoplay; encrypted-media" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="http://hpc.psy.ntu.edu.tw/info/05/css.html" frameborder="0" allow="autoplay; encrypted-media" allowfullscreen></iframe>

# %% [markdown]
# ## 2 Web Crawlers

# %%
# !pip install scrapy

# %% [markdown]
# ### 2.1 LXML & Scrapy
# You can find more about XPath syntax <a href="https://www.w3schools.com/xml/xpath_syntax.asp">here</a>.

# %% [markdown]
# #### 2.1.1 Example 1:
# <p><b>1</b>2<b>3</b></p>

# %%
data='<p><b>1</b>2<b>3</b></p>'

# %% [markdown]
# ##### 2.1.1.1 Using LXML

# %%
import lxml.html
t=lxml.html.fromstring(data)
print(t,t[0],t[1])
print(t.text,t[0].text,t[1].text)
# Out:
# <Element p at 0x7f8e903edd60> <Element b at 0x7f8e806d0ef0> <Element b at 0x7f8e90074f40>
# None 1 3

# %% [markdown]
# /用於獲取直接子節點，//用於獲取子孫節點。

# %%
print(t.xpath('//p'))
print(t.xpath('//p')[0].text_content()) #123 #ptt裡面的標題+新文+引言
print(t.xpath('//p')[0].getchildren()) #1,3
print(t.xpath('//b')) #1,3
print(t.xpath('//p/text()')) #2 #ptt裡面的新文
# Out:
# [<Element p at 0x7f8e903edd60>]
# 123
# [<Element b at 0x7f8e903e7f90>, <Element b at 0x7f8e60072a90>]
# [<Element b at 0x7f8e9040acc0>, <Element b at 0x7f8e9040ae00>]
# ['2']

# %% [markdown]
# ##### 2.1.1.2 Using Scrapy Selector

# %%
from scrapy.selector import Selector

# %%
t=Selector(text=data)
print(t)
# Out:
# <Selector xpath=None data='<html><body><p><b>1</b>2<b>3</b></p><...'>

# %%
t.xpath('//b').extract()
# Out:
# ['<b>1</b>', '<b>3</b>']

# %%
print(t.xpath('//p').extract())
print(t.xpath('//p/text()').extract())
print(t.xpath('//p/text()').extract_first())
print(t.xpath('//p/*').extract())
print(t.xpath('//p').re('\d'))
# Out:
# ['<p><b>1</b>2<b>3</b></p>']
# ['2']
# 2
# ['<b>1</b>', '<b>3</b>']
# ['1', '2', '3']

# %%
print(t.xpath('//b').extract())
print(t.xpath('//b/text()').extract())
print(t.xpath('//b/text()').extract_first())
# Out:
# ['<b>1</b>', '<b>3</b>']
# ['1', '3']
# 1

# %% [markdown]
# #### 2.1.2 Example 2:
# <table>
# <tr><td>11</td><td>12</td></tr>
# <tr><td>21</td><td><a href="http://ptt.cc">22</a></td></tr>
# <tr><td>31</td><td>32</td></tr>
# </table>

# %%
data='''
<table>
    <tr>
        <td>11</td>
        <td>12</td>
    </tr>
    <tr>
        <td>21</td>
        <td>
            <a href="http://ptt.cc">22</a>
        </td>
    </tr>
    <tr>
        <td>31</td>
        <td>32</td>
    </tr>
</table>'''

# %% [markdown]
# ##### 2.1.2.1 Using LXML

# %%
t=lxml.html.fromstring(data)
x=t.xpath('//td')
print(x[0].getparent().getnext().getchildren())
print(t.xpath('//a/@href'))
print(t.xpath('//a/text()'))
# Out:
# [<Element td at 0x7f8ea18a90e0>, <Element td at 0x7f8ea18a9090>]
# ['http://ptt.cc']
# ['22']

# %% [markdown]
# ##### 2.1.2.1 Using Scrapy Selector

# %%
from scrapy.selector import Selector
t=Selector(text=data)
print(t.xpath('//td'))
print(t.xpath('//td/..')[1].xpath('*/text()'))
# Out:
# [<Selector xpath='//td' data='<td>11</td>'>, <Selector xpath='//td' data='<td>12</td>'>, <Selector xpath='//td' data='<td>21</td>'>, <Selector xpath='//td' data='<td><a href="http://ptt.cc">22</a></td>'>, <Selector xpath='//td' data='<td>31</td>'>, <Selector xpath='//td' data='<td>32</td>'>]
# [<Selector xpath='*/text()' data='21'>]

# %%
print(t.xpath('//a/@href'))
print(t.xpath('//a/@href').extract())
print(t.xpath('//a/text()'))
print(t.xpath('//a/text()').extract())
# Out:
# [<Selector xpath='//a/@href' data='http://ptt.cc'>]
# ['http://ptt.cc']
# [<Selector xpath='//a/text()' data='22'>]
# ['22']

# %% [markdown]
# #### 2.1.3 Collecting links from PTT

# %% [markdown]
# ##### 2.1.3.1 Using LXML

# %%
import lxml.html
import urllib.request
u='http://www.ptt.cc/bbs/Boy-Girl/'
search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E7%94%B7%E5%A5%B3%E6%9D%BF%E6%9D%BF%E8%A6%8F
# 搜尋看板內 ChenDao 的文章 /bbs/Boy-Girl/search?q=author%3AChenDao
# Fw: [情報] 34th 小天使招考（9/5～9/15）  /bbs/Boy-Girl/M.1631115662.A.014.html
# 搜尋同標題文章 /bbs/Boy-Girl/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D+34th+%E5%B0%8F%E5%A4%A9%E4%BD%BF%E6%8B%9B%E8%80%83%EF%BC%889%2F5%EF%BD%9E9%2F15%EF%BC%89+
# 搜尋看板內 ChenDao 的文章 /bbs/Boy-Girl/search?q=author%3AChenDao

# %% [markdown]
# ##### 2.1.3.2 Using Scrapy

# %%
import scrapy
from scrapy.crawler import CrawlerProcess

# %%
class MySpider(scrapy.Spider):
    name="ptt"
    start_urls=["http://www.ptt.cc/bbs/Boy-Girl/"]
    def parse(self, response):
        for link in response.xpath('//a'):
            print(link.xpath('text()').extract())
            print(link.xpath('@href').extract())

# %%
process = CrawlerProcess({
    'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'
})
process.crawl(MySpider)
process.start()
# Out:
# 2021-10-23 18:54:58 [scrapy.utils.log] INFO: Scrapy 2.5.1 started (bot: scrapybot)
# 2021-10-23 18:54:58 [scrapy.utils.log] INFO: Versions: lxml 4.6.3.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 21.7.0, Python 3.8.8 (default, Apr 13 2021, 12:59:45) - [Clang 10.0.0 ], pyOpenSSL 20.0.1 (OpenSSL 1.1.1k  25 Mar 2021), cryptography 3.4.7, Platform macOS-10.16-x86_64-i386-64bit
# 2021-10-23 18:54:58 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2021-10-23 18:54:58 [scrapy.crawler] INFO: Overridden settings:
# {'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'}
# 2021-10-23 18:54:58 [scrapy.extensions.telnet] INFO: Telnet Password: 93ab352b83b18def
# 2021-10-23 18:54:58 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2021-10-23 18:54:58 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2021-10-23 18:54:58 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2021-10-23 18:54:58 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2021-10-23 18:54:58 [scrapy.core.engine] INFO: Spider opened
# 2021-10-23 18:54:58 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2021-10-23 18:54:58 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2021-10-23 18:54:58 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.ptt.cc/bbs/Boy-Girl/> from <GET http://www.ptt.cc/bbs/Boy-Girl/>
# 2021-10-23 18:54:59 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET https://www.ptt.cc/bbs/Boy-Girl/index.html> from <GET https://www.ptt.cc/bbs/Boy-Girl/>
# 2021-10-23 18:54:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.ptt.cc/bbs/Boy-Girl/index.html> (referer: None)
# 2021-10-23 18:54:59 [scrapy.core.engine] INFO: Closing spider (finished)
# 2021-10-23 18:54:59 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 1065,
#  'downloader/request_count': 3,
#  'downloader/request_method_count/GET': 3,
#  'downloader/response_bytes': 5981,
#  'downloader/response_count': 3,
#  'downloader/response_status_count/200': 1,
#  'downloader/response_status_count/301': 1,
#  'downloader/response_status_count/302': 1,
#  'elapsed_time_seconds': 1.100499,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2021, 10, 23, 10, 54, 59, 723057),
#  'httpcompression/response_bytes': 22235,
#  'httpcompression/response_count': 1,
#  'log_count/DEBUG': 3,
#  'log_count/INFO': 10,
#  'memusage/max': 299843584,
#  'memusage/startup': 299827200,
#  'response_received_count': 1,
#  'scheduler/dequeued': 3,
#  'scheduler/dequeued/memory': 3,
#  'scheduler/enqueued': 3,
#  'scheduler/enqueued/memory': 3,
#  'start_time': datetime.datetime(2021, 10, 23, 10, 54, 58, 622558)}
# 2021-10-23 18:54:59 [scrapy.core.engine] INFO: Spider closed (finished)
# ['批踢踢實業坊']
# ['/bbs/']
# ['Boy-Girl']
# ['/bbs/Boy-Girl/index.html']
# ['關於我們']
# ['/about.html']
# ['聯絡資訊']
# ['/contact.html']
# ['看板']
# ['/bbs/Boy-Girl/index.html']
# ['精華區']
# ['/man/Boy-Girl/index.html']
# ['最舊']
# ['/bbs/Boy-Girl/index1.html']
# ['‹ 上頁']
# ['/bbs/Boy-Girl/index5521.html']
# ['下頁 ›']
# []
# ['最新']
# ['/bbs/Boy-Girl/index.html']
# ['Re: [討論] 說謊 該如何睡得安穩']
# ['/bbs/Boy-Girl/M.1634962743.A.ADC.html']
# ['搜尋同標題文章']
# ['/bbs/Boy-Girl/search?q=thread%3A%5B%E8%A8%8E%E8%AB%96%5D+%E8%AA%AA%E8%AC%8A+%E8%A9%B2%E5%A6%82%E4%BD%95%E7%9D%A1%E5%BE%97%E5%AE%89%E7%A9%A9']
# ['搜尋看板內 Latte5566 的文章']
# ['/bbs/Boy-Girl/search?q=author%3ALatte5566']
# ['[討論] 有斷絕關係切結書?']
# ['/bbs/Boy-Girl/M.1634965200.A.4A6.html']
# ['搜尋同標題文章']
# ['/bbs/Boy-Girl/search?q=thread%3A%5B%E8%A8%8E%E8%AB%96%5D+%E6%9C%89%E6%96%B7%E7%B5%95%E9%97%9C%E4%BF%82%E5%88%87%E7%B5%90%E6%9B%B8%3F']
# ['搜尋看板內 kaki1231 的文章']
# ['/bbs/Boy-Girl/search?q=author%3Akaki1231']
# ['Re: [討論] 說謊 該如何睡得安穩']
# ['/bbs/Boy-Girl/M.1634965863.A.3B3.html']
# ['搜尋同標題文章']
# ['/bbs/Boy-Girl/search?q=thread%3A%5B%E8%A8%8E%E8%AB%96%5D+%E8%AA%AA%E8%AC%8A+%E8%A9%B2%E5%A6%82%E4%BD%95%E7%9D%A1%E5%BE%97%E5%AE%89%E7%A9%A9']
# ['搜尋看板內 skinjazz 的文章']
# ['/bbs/Boy-Girl/search?q=author%3Askinjazz']
# ['[討論] 對心靈雞湯的駁斥謬誤']
# ['/bbs/Boy-Girl/M.1634967945.A.50E.html']
# ['搜尋同標題文章']
# ['/bbs/Boy-Girl/search?q=thread%3A%5B%E8%A8%8E%E8%AB%96%5D+%E5%B0%8D%E5%BF%83%E9%9D%88%E9%9B%9E%E6%B9%AF%E7%9A%84%E9%A7%81%E6%96%A5%E8%AC%AC%E8%AA%A4']
# ['搜尋看板內 rabinson 的文章']
# ['/bbs/Boy-Girl/search?q=author%3Arabinson']
# ['Re: [討論] 如何安撫女友對房貸的恐懼?']
# ['/bbs/Boy-Girl/M.1634970651.A.FBA.html']
# ['搜尋同標題文章']
# ['/bbs/Boy-Girl/search?q=thread%3A%5B%E8%A8%8E%E8%AB%96%5D+%E5%A6%82%E4%BD%95%E5%AE%89%E6%92%AB%E5%A5%B3%E5%8F%8B%E5%B0%8D%E6%88%BF%E8%B2%B8%E7%9A%84%E6%81%90%E6%87%BC%3F']
# ['搜尋看板內 pauljet 的文章']
# ['/bbs/Boy-Girl/search?q=author%3Apauljet']
# ['Re: [討論] 如何安撫女友對房貸的恐懼?']
# ['/bbs/Boy-Girl/M.1634972867.A.40A.html']
# ['搜尋同標題文章']
# ['/bbs/Boy-Girl/search?q=thread%3A%5B%E8%A8%8E%E8%AB%96%5D
search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E6%AA%A2%E8%88%89%E6%A0%BC%E5%BC%8F%E6%95%99%E5%AD%B8']
# ['搜尋看板內 ChenDao 的文章']
# ['/bbs/Boy-Girl/search?q=author%3AChenDao']
# ['[公告] 有關於"問卷文申請"']
# ['/bbs/Boy-Girl/M.1560802697.A.8E6.html']
# ['搜尋同標題文章']
# ['/bbs/Boy-Girl/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E6%9C%89%E9%97%9C%E6%96%BC%22%E5%95%8F%E5%8D%B7%E6%96%87%E7%94%B3%E8%AB%8B%22']
# ['搜尋看板內 ChenDao 的文章']
# ['/bbs/Boy-Girl/search?q=author%3AChenDao']
# ['[公告] 男女板板規']
# ['/bbs/Boy-Girl/M.1565730811.A.BDC.html']
# ['搜尋同標題文章']
# ['/bbs/Boy-Girl/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E7%94%B7%E5%A5%B3%E6%9D%BF%E6%9D%BF%E8%A6%8F']
# ['搜尋看板內 ChenDao 的文章']
# ['/bbs/Boy-Girl/search?q=author%3AChenDao']
# ['Fw: [情報] 34th 小天使招考（9/5～9/15） ']
# ['/bbs/Boy-Girl/M.1631115662.A.014.html']
# ['搜尋同標題文章']
# ['/bbs/Boy-Girl/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D+34th+%E5%B0%8F%E5%A4%A9%E4%BD%BF%E6%8B%9B%E8%80%83%EF%BC%889%2F5%EF%BD%9E9%2F15%EF%BC%89+']
# ['搜尋看板內 ChenDao 的文章']
# ['/bbs/Boy-Girl/search?q=author%3AChenDao']

# %% [markdown]
# #### 2.1.4 Analyzing texts from PTT

# %% [markdown]
# ##### 2.1.4.1 Using LXML

# %%
import urllib, lxml.html
URL='http://www.ptt.cc'
URN='/bbs/Boy-Girl/M.1394964006.A.850.html'
h={'User-Agent':'Mozilla/5.0'}
r=urllib.request.Request(URL+URN,headers=h)
data=urllib.request.urlopen(r).read()
t=lxml.html.fromstring(data.decode('utf-8'))
print(t.text_content()) #整頁
# Out:
#
#
#
#
#
#
# Re: [心情] 我要怎麼原諒那個人 - 看板 Boy-Girl - 批踢踢實業坊
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		批踢踢實業坊
# 		›
# 		看板 Boy-Girl
# 		關於我們
# 		聯絡資訊
#
#
#
#
# 		返回看板
#
#
#
#
#     作者wbson (Simple Power)站內Boy-Girl標題Re: [心情] 我要怎麼原諒那個人時間Sun Mar 16 18:00:03 2014
# 想一想，事情最壞可以多壞？假如那個人成為你的老公，你被內射了幾次，小孩生下後
#
# 你不清楚他失業了沒，反正他不拿錢回家，外面欠一屁股債，還跟外遇對象也生了三個
#
# 外遇對象是越南小吃店的員工，被警察抓到後登上社會版頭條，結果說去驗DNA發現
#
# 還不是你老公的種，所以小孩要被遣返，有人跳出來說你應該扶養這三個小孩
#
# 記者打電話給你，網友肉搜你，名嘴討論你，債主騷擾你
#
#
# 又或者看一下三立或民視的鄉土劇，它們節目收視率好不是沒有原因的，
#
# 因為大多數人的生活中總是可以找到跟劇中情節類似的故事。
#
#
# 這個世界可以很殘忍可可怕的，在那麼多套杯具裡面，你選一個用了八九年之久，
#
# 現在它破了，你把它丟掉正好。有人會為了自己丟掉的垃圾被資源回收婆婆撿回家去用
#
# 而傷心落淚嗎？
#
#
#
# ※ 引述《Qion (珍惜)》之銘言：
# : 在一個人身上花了八九年的時間
# : 因為既有的問題無法解決 關於結婚也無法達成共識
# : 我們分手了
# : 他不到三個月就交了新的 是以前就常一起出國玩
# : 會去接送的人 為什麼是她。。。
# : 現在聽說要結婚(一年多了)
# : 怎麼辦呢我毫無意識的眼淚掉了滿地
# : 這個爛人
# : 共同的朋友不敢告訴我但還是被我知道了
# : 這個人我無法原諒
# : 可是不原諒要怎麼辦 放過自己否則要怎麼過日子?
# : 好想選擇一個容易的 逃避一切痛苦的方法
# : 可是我能嗎?
# : 我這麼努力的 好好活著 重新建立我的生活
# : 一直對抗著不被珍惜的恐懼 被背叛被丟棄的痛苦
# : 可是我的堅強還是被打垮
# : 真的很恨他 如果可以不遇見 該有多好
#
# --
# ※ 發信站: 批踢踢實業坊(ptt.cc)
# ◆ From: 172.2.206.224
# 推 winds19903:推最後一段 03/16 19:25
#
#
#
#
#
#
#
#
#
#
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');

# %%
x=t.xpath('//div[@id="main-content"]')[0]
print(x.text_content()) #主文
# Out:
# 作者wbson (Simple Power)站內Boy-Girl標題Re: [心情] 我要怎麼原諒那個人時間Sun Mar 16 18:00:03 2014
# 想一想，事情最壞可以多壞？假如那個人成為你的老公，你被內射了幾次，小孩生下後
#
# 你不清楚他失業了沒，反正他不拿錢回家，外面欠一屁股債，還跟外遇對象也生了三個
#
# 外遇對象是越南小吃店的員工，被警察抓到後登上社會版頭條，結果說去驗DNA發現
#
# 還不是你老公的種，所以小孩要被遣返，有人跳出來說你應該扶養這三個小孩
#
# 記者打電話給你，網友肉搜你，名嘴討論你，債主騷擾你
#
#
# 又或者看一下三立或民視的鄉土劇，它們節目收視率好不是沒有原因的，
#
# 因為大多數人的生活中總是可以找到跟劇中情節類似的故事。
#
#
# 這個世界可以很殘忍可可怕的，在那麼多套杯具裡面，你選一個用了八九年之久，
#
# 現在它破了，你把它丟掉正好。有人會為了自己丟掉的垃圾被資源回收婆婆撿回家去用
#
# 而傷心落淚嗎？
#
#
#
# ※ 引述《Qion (珍惜)》之銘言：
# : 在一個人身上花了八九年的時間
# : 因為既有的問題無法解決 關於結婚也無法達成共識
# : 我們分手了
# : 他不到三個月就交了新的 是以前就常一起出國玩
# : 會去接送的人 為什麼是她。。。
# : 現在聽說要結婚(一年多了)
# : 怎麼辦呢我毫無意識的眼淚掉了滿地
# : 這個爛人
# : 共同的朋友不敢告訴我但還是被我知道了
# : 這個人我無法原諒
# : 可是不原諒要怎麼辦 放過自己否則要怎麼過日子?
# : 好想選擇一個容易的 逃避一切痛苦的方法
# : 可是我能嗎?
# : 我這麼努力的 好好活著 重新建立我的生活
# : 一直對抗著不被珍惜的恐懼 被背叛被丟棄的痛苦
# : 可是我的堅強還是被打垮
# : 真的很恨他 如果可以不遇見 該有多好
#
# --
# ※ 發信站: 批踢踢實業坊(ptt.cc)
# ◆ From: 172.2.206.224
# 推 winds19903:推最後一段 03/16 19:25

# %%
y=t.xpath('//div[@id="main-content"]/text()')
print(y) #新文
print(''.join(y))
# Out:
# ['\n想一想，事情最壞可以多壞？假如那個人成為你的老公，你被內射了幾次，小孩生下後\n\n你不清楚他失業了沒，反正他不拿錢回家，外面欠一屁股債，還跟外遇對象也生了三個\n\n外遇對象是越南小吃店的員工，被警察抓到後登上社會版頭條，結果說去驗DNA發現\n\n還不是你老公的種，所以小孩要被遣返，有人跳出來說你應該扶養這三個小孩\n\n記者打電話給你，網友肉搜你，名嘴討論你，債主騷擾你\n\n\n又或者看一下三立或民視的鄉土劇，它們節目收視率好不是沒有原因的，\n\n因為大多數人的生活中總是可以找到跟劇中情節類似的故事。\n\n\n這個世界可以很殘忍可可怕的，在那麼多套杯具裡面，你選一個用了八九年之久，\n\n現在它破了，你把它丟掉正好。有人會為了自己丟掉的垃圾被資源回收婆婆撿回家去用\n\n而傷心落淚嗎？\n\n\n\n', '\n--\n', '◆ From: 172.2.206.224\n']
#
# 想一想，事情最壞可以多壞？假如那個人成為你的老公，你被內射了幾次，小孩生下後
#
# 你不清楚他失業了沒，反正他不拿錢回家，外面欠一屁股債，還跟外遇對象也生了三個
#
# 外遇對象是越南小吃店的員工，被警察抓到後登上社會版頭條，結果說去驗DNA發現
#
# 還不是你老公的種，所以小孩要被遣返，有人跳出來說你應該扶養這三個小孩
#
# 記者打電話給你，網友肉搜你，名嘴討論你，債主騷擾你
#
#
# 又或者看一下三立或民視的鄉土劇，它們節目收視率好不是沒有原因的，
#
# 因為大多數人的生活中總是可以找到跟劇中情節類似的故事。
#
#
# 這個世界可以很殘忍可可怕的，在那麼多套杯具裡面，你選一個用了八九年之久，
#
# 現在它破了，你把它丟掉正好。有人會為了自己丟掉的垃圾被資源回收婆婆撿回家去用
#
# 而傷心落淚嗎？
#
#
#
#
# --
# ◆ From: 172.2.206.224

# %%
z=t.xpath('//span[@class="f6"]')
for i in z:
 print(i.text) #引言
# Out:
# : 在一個人身上花了八九年的時間
#
# : 因為既有的問題無法解決 關於結婚也無法達成共識
#
# : 我們分手了
#
# : 他不到三個月就交了新的 是以前就常一起出國玩
#
# : 會去接送的人 為什麼是她。。。
#
# : 現在聽說要結婚(一年多了)
#
# : 怎麼辦呢我毫無意識的眼淚掉了滿地
#
# : 這個爛人
#
# : 共同的朋友不敢告訴我但還是被我知道了
#
# : 這個人我無法原諒
#
# : 可是不原諒要怎麼辦 放過自己否則要怎麼過日子?
#
# : 好想選擇一個容易的 逃避一切痛苦的方法
#
# : 可是我能嗎?
#
# : 我這麼努力的 好好活著 重新建立我的生活
#
# : 一直對抗著不被珍惜的恐懼 被背叛被丟棄的痛苦
#
# : 可是我的堅強還是被打垮
#
# : 真的很恨他 如果可以不遇見 該有多好

# %%
H=t.xpath('//*[contains(text(),"恨")]')[0]
print(H.text) #含恨
# Out:
# : 真的很恨他 如果可以不遇見 該有多好

# %% [markdown]
# ##### 2.1.4.2 Using Scrapy

# %%
import scrapy
from scrapy.crawler import CrawlerProcess

# %%
class Spider0(scrapy.Spider): #source
    name="ptt"
    start_urls=["http://www.ptt.cc/bbs/Boy-Girl/M.1394964006.A.850.html"]
    def parse(self, response):
        print(response.text)
        
class Spider1(scrapy.Spider): #body
    name="ptt"
    start_urls=["http://www.ptt.cc/bbs/Boy-Girl/M.1394964006.A.850.html"]
    def parse(self, response):
        print(''.join(response.xpath("//body//text()").extract()))
        
class Spider2(scrapy.Spider): #新文
    name="ptt"
    start_urls=["http://www.ptt.cc/bbs/Boy-Girl/M.1394964006.A.850.html"]
    def parse(self, response):
        print(response.xpath('//div[@id="main-content"]/text()').extract()[0].strip())

class Spider3(scrapy.Spider): #引言
    name="ptt"
    start_urls=["http://www.ptt.cc/bbs/Boy-Girl/M.1394964006.A.850.html"]
    def parse(self, response):
        print(''.join(response.xpath('//span[@class="f6"]/text()').extract()))
        
class Spider4(scrapy.Spider): #含恨
    name="ptt"
    start_urls=["http://www.ptt.cc/bbs/Boy-Girl/M.1394964006.A.850.html"]
    def parse(self, response):
        print(response.xpath('//*[contains(text(),"恨")]/text()').extract())

# %%
process = CrawlerProcess()
process.crawl(Spider0)
process.start()
# Out:
# 2018-10-10 20:22:58 [scrapy.utils.log] INFO: Scrapy 1.5.1 started (bot: scrapybot)
# 2018-10-10 20:22:58 [scrapy.utils.log] INFO: Versions: lxml 4.2.1.0, libxml2 2.9.8, cssselect 1.0.3, parsel 1.5.0, w3lib 1.19.0, Twisted 18.7.0, Python 3.6.5 |Anaconda, Inc.| (default, Apr 26 2018, 08:42:37) - [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)], pyOpenSSL 18.0.0 (OpenSSL 1.0.2o  27 Mar 2018), cryptography 2.2.2, Platform Darwin-17.7.0-x86_64-i386-64bit
# 2018-10-10 20:22:58 [scrapy.crawler] INFO: Overridden settings: {}
# 2018-10-10 20:22:58 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2018-10-10 20:22:59 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2018-10-10 20:22:59 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2018-10-10 20:22:59 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2018-10-10 20:22:59 [scrapy.core.engine] INFO: Spider opened
# 2018-10-10 20:22:59 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2018-10-10 20:22:59 [scrapy.extensions.telnet] DEBUG: Telnet console listening on 127.0.0.1:6023
# 2018-10-10 20:22:59 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.ptt.cc/bbs/Boy-Girl/M.1394964006.A.850.html> from <GET http://www.ptt.cc/bbs/Boy-Girl/M.1394964006.A.850.html>
# 2018-10-10 20:22:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.ptt.cc/bbs/Boy-Girl/M.1394964006.A.850.html> (referer: None)
# 2018-10-10 20:22:59 [scrapy.core.engine] INFO: Closing spider (finished)
# 2018-10-10 20:22:59 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 552,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 4310,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 1,
#  'downloader/response_status_count/301': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2018, 10, 10, 12, 22, 59, 753312),
#  'log_count/DEBUG': 3,
#  'log_count/INFO': 7,
#  'memusage/max': 69537792,
#  'memusage/startup': 69537792,
#  'response_received_count': 1,
#  'scheduler/dequeued': 2,
#  'scheduler/dequeued/memory': 2,
#  'scheduler/enqueued': 2,
#  'scheduler/enqueued/memory': 2,
#  'start_time': datetime.datetime(2018, 10, 10, 12, 22, 59, 79064)}
# 2018-10-10 20:22:59 [scrapy.core.engine] INFO: Spider closed (finished)
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>Re: [心情] 我要怎麼原諒那個人 - 看板 Boy-Girl - 批踢踢實業坊</title>
# <meta name="robots" content="all">
# <meta name="keywords" content="Ptt BBS 批踢踢">
# <meta name="description" content="想一想，事情最壞可以多壞？假如那個人成為你的老公，你被內射了幾次，小孩生下後
# 你不清楚他失業了沒，反正他不拿錢回家，外面欠一屁股債，還跟外遇對象也生了三個
# 外遇對象是越南小吃店的員工，被警察抓到後登上社會版頭條，結果說去驗DNA發現
# 還不是你老公的種，所以小孩要被遣返，有人跳出來說你應該扶養這三個小孩
# 記者打電話給你，網友肉搜你，名嘴討論你，債主騷擾你
# ">
# <meta property="og:site_name" content="Ptt 批踢踢實業坊">
# <meta property="og:title" content="Re: [心情] 我要怎麼原諒那個人">
# <meta property="og:description" content="想一想，事情最壞可以多壞？假如那個人成為你的老公，你被內射了幾次，小孩生下後
# 你不清楚他失業了沒，反正他不拿錢回家，外面欠一屁股債，還跟外遇對象也生了三個
# 外遇對象是越南小吃店的員工，被警察抓到後登上社會版頭條，結果說去驗DNA發現
# 還不是你老公的種，所以小孩要被遣返，有人跳出來說你應該扶養這三個小孩
# 記者打電話給你，網友肉搜你，名嘴討論你，債主騷擾你
# ">
# <link rel="canonical" href="https://www.ptt.cc/bbs/Boy-Girl/M.1394964006.A.850.html">
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="fb-root"></div>
# <script>(function(d, s, id) {
# var js, fjs = d.getElementsByTagName(s)[0];
# if (d.getElementById(id)) return;
# js = d.createElement(s); js.id = id;
# js.src = "//connect.facebook.net/en_US/all.js#xfbml=1";
# fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));</script>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Boy-Girl/index.html"><span class="board-label">看板 </span>Boy-Girl</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
# <div id="navigation-container">
# 	<div id="navigation" class="bbs-content">
# 		<a class="board" href="/bbs/Boy-Girl/index.html">返回看板</a>
# 		<div class="bar"></div>
# 		<div class="share">
# 			<span>分享</span>
# 			<div class="fb-like" data-send="false" data-layout="button_count" data-width="90" data-show-faces="false" data-href="http://www.ptt.cc/bbs/Boy-Girl/M.1394964006.A.850.html"></div>
#
# 			<div class="g-plusone" data-size="medium"></div>
# <script type="text/javascript">
# window.___gcfg = {lang: 'zh-TW'};
# (function() {
# var po = document.createElement('script'); po.type = 'text/javascript'; po.async = true;
# po.src = 'https://apis.google.com/js/plusone.js';
# var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(po, s);
# })();
# </script>
#
# 		</div>
# 	</div>
# </div>
# <div id="main-container">
#     <div id="main-content" class="bbs-screen bbs-content"><div class="article-metaline"><span class="article-meta-tag">作者</span><span class="article-meta-value">wbson (Simple Power)</span></div><div class="article-metaline-right"><span class="article-meta-tag">站內</span><span class="article-meta-value">Boy-Girl</span></div><div class="article-metaline"><span class="article-meta-tag">標題</span><span class="article-meta-value">Re: [心情] 我要怎麼原諒那個人</span></div><div class="article-metaline"><span class="article-meta-tag">時間</span><span class="article-meta-value">Sun Mar 16 18:00:03 2014</span></div>
# 想一想，事情最壞可以多壞？假如那個人成為你的老公，你被內射了幾次，小孩生下後
#
# 你不清楚他失業了沒，反正他不拿錢回家，外面欠一屁股債，還跟外遇對象也生了三個
#
# 外遇對象是越南小吃店的員工，被警察抓到後登上社會版頭條，結果說去驗DNA發現
#
# 還不是你老公的種，所以小孩要被遣返，有人跳出來說你應該扶養這三個小孩
#
# 記者打電話給你，網友肉搜你，名嘴討論你，債主騷擾你
#
#
# 又或者看一下三立或民視的鄉土劇，它們節目收視率好不是沒有原因的，
#
# 因為大多數人的生活中總是可以找到跟劇中情節類似的故事。
#
#
# 這個世界可以很殘忍可可怕的，在那麼多套杯具裡面，你選一個用了八九年之久，
#
# 現在它破了，你把它丟掉正好。有人會為了自己丟掉的垃圾被資源回收婆婆撿回家去用
#
# 而傷心落淚嗎？
#
#
#
# <span class="f2">※ 引述《Qion (珍惜)》之銘言：
# </span><span class="f6">: 在一個人身上花了八九年的時間
# </span><span class="f6">: 因為既有的問題無法解決 關於結婚也無法達成共識
# </span><span class="f6">: 我們分手了
# </span><span class="f6">: 他不到三個月就交了新的 是以前就常一起出國玩
# </span><span class="f6">: 會去接送的人 為什麼是她。。。
# </span><span class="f6">: 現在聽說要結婚(一年多了)
# </span><span class="f6">: 怎麼辦呢我毫無意識的眼淚掉了滿地
# </span><span class="f6">: 這個爛人
# </span><span class="f6">: 共同的朋友不敢告訴我但還是被我知道了
# </span><span class="f6">: 這個人我無法原諒
# </span><span class="f6">: 可是不原諒要怎麼辦 放過自己否則要怎麼過日子?
# </span><span class="f6">: 好想選擇一個容易的 逃避一切痛苦的方法
# </span><span class="f6">: 可是我能嗎?
# </span><span class="f6">: 我這麼努力的 好好活著 重新建立我的生活
# </span><span class="f6">: 一直對抗著不被珍惜的恐懼 被背叛被丟棄的痛苦
# </span><span class="f6">: 可是我的堅強還是被打垮
# </span><span class="f6">: 真的很恨他 如果可以不遇見 該有多好
# </span>
# --
# <span class="f2">※ 發信站: 批踢踢實業坊(ptt.cc)
# </span>◆ From: 172.2.206.224
# <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">winds19903</span><span class="f3 push-content">:推最後一段</span><span class="push-ipdatetime"> 03/16 19:25
# </span></div></div>
#
#     <div id="article-polling" data-pollurl="/poll/Boy-Girl/M.1394964006.A.850.html?cacheKey=2100-98589289&amp;offset=1501&amp;offset-sig=524863f83251ebdca4f0be5e2b26cbe7059a9c99" data-longpollurl="/v1/longpoll?id=76cff78a4ab7fe3c25ed6ed834e5f07b4ccd1909" data-offset="1501"></div>
#
#
#
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.25/bbs.js"></script>
#
#     </body>
# </html>

# %% [markdown]
# #### 2.1.4 Sending HTML forms

# %% [markdown]
# ##### 2.1.4.1 Using urllib

# %%
# Not working without sending required info:
import urllib.request 
u='http://www.ptt.cc/bbs/Gossiping/'
h={'User-Agent':'Mozilla/5.0'}
r=urllib.request.Request(u,headers=h)
data=urllib.request.urlopen(r).read()
print(data.decode('utf-8'))
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div class="bbs-screen bbs-content">
#     <div class="over18-notice">
#         <p>本網站已依網站內容分級規定處理</p>
#
#         <p>警告︰您即將進入之看板內容需滿十八歲方可瀏覽。</p>
#
#         <p>若您尚未年滿十八歲，請點選離開。若您已滿十八歲，亦不可將本區之內容派發、傳閱、出售、出租、交給或借予年齡未滿18歲的人士瀏覽，或將本網站內容向該人士出示、播放或放映。</p>
#     </div>
# </div>
#
# <div class="bbs-screen bbs-content center clear">
#     <form action="/ask/over18" method="post">
#         <input type="hidden" name="from" value="/bbs/Gossiping/index.html">
#         <div class="over18-button-container">
#             <button class="btn-big" type="submit" name="yes" value="yes">我同意，我已年滿十八歲<br><small>進入</small></button>
#         </div>
#         <div class="over18-button-container">
#             <button class="btn-big" type="submit" name="no" value="no">未滿十八歲或不同意本條款<br><small>離開</small></button>
#         </div>
#     </form>
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
#
#     </body>
# </html>

# %%
# Still not working even with required information:
from urllib import parse,request
URL='https://www.ptt.cc'
URN='/ask/over18'
q=parse.urlencode({'yes':'yes','from':'/bbs/Gossiping/'})
q=q.encode('utf-8')
h={'User-Agent':'Mozilla/5.0'}
req=request.Request(URL+URN,q,h)
response=request.urlopen(req)
data=response.read()
print(data.decode('utf-8'))
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div class="bbs-screen bbs-content">
#     <div class="over18-notice">
#         <p>本網站已依網站內容分級規定處理</p>
#
#         <p>警告︰您即將進入之看板內容需滿十八歲方可瀏覽。</p>
#
#         <p>若您尚未年滿十八歲，請點選離開。若您已滿十八歲，亦不可將本區之內容派發、傳閱、出售、出租、交給或借予年齡未滿18歲的人士瀏覽，或將本網站內容向該人士出示、播放或放映。</p>
#     </div>
# </div>
#
# <div class="bbs-screen bbs-content center clear">
#     <form action="/ask/over18" method="post">
#         <input type="hidden" name="from" value="/bbs/Gossiping/index.html">
#         <div class="over18-button-container">
#             <button class="btn-big" type="submit" name="yes" value="yes">我同意，我已年滿十八歲<br><small>進入</small></button>
#         </div>
#         <div class="over18-button-container">
#             <button class="btn-big" type="submit" name="no" value="no">未滿十八歲或不同意本條款<br><small>離開</small></button>
#         </div>
#     </form>
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
#
#     </body>
# </html>

# %%
# Working version with a cookie set:
from urllib import parse,request
URL='https://www.ptt.cc'
URN='/ask/over18'
q=parse.urlencode({'yes':'yes','from':'/bbs/Gossiping/'})
q=q.encode('utf-8')
h={'Cookie':'over18=1','User-Agent':'Mozilla/5.0'}
req=request.Request(URL+URN,q,h)
response=request.urlopen(req)
data=response.read()
print(data.decode('utf-8'))
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
#
# <div id="main-container">
# 	<div id="action-bar-container">
# 		<div class="action-bar">
# 			<div class="btn-group btn-group-dir">
# 				<a class="btn selected" href="/bbs/Gossiping/index.html">看板</a>
# 				<a class="btn" href="/man/Gossiping/index.html">精華區</a>
# 			</div>
# 			<div class="btn-group btn-group-paging">
# 				<a class="btn wide" href="/bbs/Gossiping/index1.html">最舊</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index39510.html">&lsaquo; 上頁</a>
# 				<a class="btn wide disabled">下頁 &rsaquo;</a>
# 				<a class="btn wide" href="/bbs/Gossiping/
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
#
#     </body>
# </html>

# %% [markdown]
# ##### 2.1.4.2 Using Scrapy

# %%
import scrapy
from scrapy.http import Request, FormRequest
from scrapy.crawler import CrawlerProcess

class Spider(scrapy.Spider):
    name="ptt"
    
    def start_requests(self):
        yield Request(url='https://www.ptt.cc/ask/over18',cookies={'Cookie':'over18=1','User-Agent':'Mozilla/5.0'},callback=self.login)
        
    def login(self, response):
        yield FormRequest.from_response(
            response,
            formdata={'yes':'yes','from':'/bbs/Gossiping/'},
            callback=self.parse
        )
        
    def parse(self,response):
        print(response.text)
        
        
process = CrawlerProcess()
process.crawl(Spider)
process.start()
# Out:
# 2018-10-10 21:04:30 [scrapy.utils.log] INFO: Scrapy 1.5.1 started (bot: scrapybot)
# 2018-10-10 21:04:30 [scrapy.utils.log] INFO: Versions: lxml 4.2.1.0, libxml2 2.9.8, cssselect 1.0.3, parsel 1.5.0, w3lib 1.19.0, Twisted 18.7.0, Python 3.6.5 |Anaconda, Inc.| (default, Apr 26 2018, 08:42:37) - [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)], pyOpenSSL 18.0.0 (OpenSSL 1.0.2o  27 Mar 2018), cryptography 2.2.2, Platform Darwin-17.7.0-x86_64-i386-64bit
# 2018-10-10 21:04:30 [scrapy.crawler] INFO: Overridden settings: {}
# 2018-10-10 21:04:30 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2018-10-10 21:04:30 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2018-10-10 21:04:30 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2018-10-10 21:04:30 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2018-10-10 21:04:30 [scrapy.core.engine] INFO: Spider opened
# 2018-10-10 21:04:30 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2018-10-10 21:04:30 [scrapy.extensions.telnet] DEBUG: Telnet console listening on 127.0.0.1:6023
# 2018-10-10 21:04:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.ptt.cc/ask/over18> (referer: None)
# 2018-10-10 21:04:31 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET https://www.ptt.cc/bbs/Gossiping/> from <POST https://www.ptt.cc/ask/over18>
# 2018-10-10 21:04:31 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET https://www.ptt.cc/bbs/Gossiping/index.html> from <GET https://www.ptt.cc/bbs/Gossiping/>
# 2018-10-10 21:04:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.ptt.cc/bbs/Gossiping/index.html> (referer: https://www.ptt.cc/ask/over18)
# 2018-10-10 21:04:31 [scrapy.core.engine] INFO: Closing spider (finished)
# 2018-10-10 21:04:31 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 1394,
#  'downloader/request_count': 4,
#  'downloader/request_method_count/GET': 3,
#  'downloader/request_method_count/POST': 1,
#  'downloader/response_bytes': 7537,
#  'downloader/response_count': 4,
#  'downloader/response_status_count/200': 2,
#  'downloader/response_status_count/302': 2,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2018, 10, 10, 13, 4, 31, 758975),
#  'log_count/DEBUG': 5,
#  'log_count/INFO': 7,
#  'memusage/max': 69443584,
#  'memusage/startup': 69443584,
#  'request_depth_max': 1,
#  'response_received_count': 2,
#  'scheduler/dequeued': 4,
#  'scheduler/dequeued/memory': 4,
#  'scheduler/enqueued': 4,
#  'scheduler/enqueued/memory': 4,
#  'start_time': datetime.datetime(2018, 10, 10, 13, 4, 30, 922779)}
# 2018-10-10 21:04:31 [scrapy.core.engine] INFO: Spider closed (finished)
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
#
# <div id="main-container">
# 	<div id="action-bar-container">
# 		<div class="action-bar">
# 			<div class="btn-group btn-group
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.25/bbs.js"></script>
#
#     </body>
# </html>

# %%
import scrapy
from scrapy.http import Request, FormRequest
from scrapy.crawler import CrawlerProcess

class Spider(scrapy.Spider):
    name="ptt"
    
    def start_requests(self):
        yield Request(url='https://www.ptt.cc/ask/over18',cookies={'Cookie':'over18=1','User-Agent':'Mozilla/5.0'},callback=self.login)
        
    def login(self, response):
        yield FormRequest.from_response(
            response,
            formdata={'yes':'yes','from':'/bbs/Gossiping/'},
            callback=self.parse
        )
        
    def parse(self,response):
        print(response.text)
        
        
process = CrawlerProcess()
process.crawl(Spider)
process.start()
# Out:
# 2018-10-10 21:07:10 [scrapy.utils.log] INFO: Scrapy 1.5.1 started (bot: scrapybot)
# 2018-10-10 21:07:10 [scrapy.utils.log] INFO: Versions: lxml 4.2.1.0, libxml2 2.9.8, cssselect 1.0.3, parsel 1.5.0, w3lib 1.19.0, Twisted 18.7.0, Python 3.6.5 |Anaconda, Inc.| (default, Apr 26 2018, 08:42:37) - [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)], pyOpenSSL 18.0.0 (OpenSSL 1.0.2o  27 Mar 2018), cryptography 2.2.2, Platform Darwin-17.7.0-x86_64-i386-64bit
# 2018-10-10 21:07:10 [scrapy.crawler] INFO: Overridden settings: {}
# 2018-10-10 21:07:10 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2018-10-10 21:07:10 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2018-10-10 21:07:10 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2018-10-10 21:07:10 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2018-10-10 21:07:10 [scrapy.core.engine] INFO: Spider opened
# 2018-10-10 21:07:10 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2018-10-10 21:07:10 [scrapy.extensions.telnet] DEBUG: Telnet console listening on 127.0.0.1:6023
# 2018-10-10 21:07:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.ptt.cc/ask/over18> (referer: None)
# 2018-10-10 21:07:10 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET https://www.ptt.cc/bbs/Gossiping/> from <POST https://www.ptt.cc/ask/over18>
# 2018-10-10 21:07:10 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET https://www.ptt.cc/bbs/Gossiping/index.html> from <GET https://www.ptt.cc/bbs/Gossiping/>
# 2018-10-10 21:07:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.ptt.cc/bbs/Gossiping/index.html> (referer: https://www.ptt.cc/ask/over18)
# 2018-10-10 21:07:11 [scrapy.core.engine] INFO: Closing spider (finished)
# 2018-10-10 21:07:11 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 1394,
#  'downloader/request_count': 4,
#  'downloader/request_method_count/GET': 3,
#  'downloader/request_method_count/POST': 1,
#  'downloader/response_bytes': 7936,
#  'downloader/response_count': 4,
#  'downloader/response_status_count/200': 2,
#  'downloader/response_status_count/302': 2,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2018, 10, 10, 13, 7, 11, 138992),
#  'log_count/DEBUG': 5,
#  'log_count/INFO': 7,
#  'memusage/max': 69701632,
#  'memusage/startup': 69701632,
#  'request_depth_max': 1,
#  'response_received_count': 2,
#  'scheduler/dequeued': 4,
#  'scheduler/dequeued/memory': 4,
#  'scheduler/enqueued': 4,
#  'scheduler/enqueued/memory': 4,
#  'start_time': datetime.datetime(2018, 10, 10, 13, 7, 10, 290699)}
# 2018-10-10 21:07:11 [scrapy.core.engine] INFO: Spider closed (finished)
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
#
# <div id="main-container">
# 	<div id="action-bar-container">
# 		<div class="action-bar">
# 			<div class="btn-group btn-group-dir">
# 				<a class="btn selected" href="/bbs/Gossiping/index.html">看板</a>
# 				<a class="btn" href="/man/Gossiping/index.html">精華區</a>
# 			</div>
# 			<div class="btn-group btn-group-paging">
# 				<a class="btn wide" href="/bbs/Gossiping/index1.html">最舊</a>
# 				<a class="btn wide" href="/bbs/Gossiping/
div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D&#43;107%2F10%2F05&#43;13%3A50%E5%8F%B0%E4%B8%AD%E5%85%AC%E6%AD%A3%E8%B7%AF%E8%8B%B1%E6%89%8D%E8%B7%AF%E6%AE%B5%E8%BB%8A%E7%A6%8D">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aq521q522">搜尋看板內 q521q522 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">10/07</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">19</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1539159328.A.3DA.html">[公告] =姆咪=八卦板主徵選報名開始=姆咪=</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">jacklyl</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%3D%E5%A7%86%E5%92%AA%3D%E5%85%AB%E5%8D%A6%E6%9D%BF%E4%B8%BB%E5%BE%B5%E9%81%B8%E5%A0%B1%E5%90%8D%E9%96%8B%E5%A7%8B%3D%E5%A7%86%E5%92%AA%3D">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Ajacklyl">搜尋看板內 jacklyl 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">10/10</div>
# 				<div class="mark">M</div>
# 			</div>
# 		</div>
#
#
#
# 	</div>
#
#
# <div class="bbs-screen bbs-footer-message">本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。</div>
#
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.25/bbs.js"></script>
#
#     </body>
# </html>

# %% [markdown]
# ### 2.2 Selenium

# %%
# !pip install selenium

# %%
from selenium import webdriver
URI='https://www.ptt.cc/bbs/Gossiping/'
driver=webdriver.Edge(executable_path="./msedgedriver")
driver.get(URI)
btn=driver.find_element_by_name('yes')
driver.save_screenshot('before_click.png')
btn.click()
driver.save_screenshot('after_click.png')
print(driver.page_source)
# Out:
# 2021-10-23 22:35:10 [py.warnings] WARNING: <ipython-input-38-e2484363da4d>:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Edge(executable_path="./msedgedriver")
#
# 2021-10-23 22:35:10 [selenium.webdriver.remote.remote_connection] DEBUG: POST http://localhost:64283/session {"capabilities": {"firstMatch": [{}], "alwaysMatch": {"browserName": "MicrosoftEdge", "pageLoadStrategy": "normal", "ms:edgeOptions": {"extensions": [], "args": []}}}, "desiredCapabilities": {"browserName": "MicrosoftEdge", "pageLoadStrategy": "normal", "ms:edgeOptions": {"extensions": [], "args": []}}}
# 2021-10-23 22:35:10 [urllib3.connectionpool] DEBUG: Starting new HTTP connection (1): localhost:64283
# 2021-10-23 22:35:16 [urllib3.connectionpool] DEBUG: http://localhost:64283 "POST /session HTTP/1.1" 200 767
# 2021-10-23 22:35:16 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2021-10-23 22:35:16 [selenium.webdriver.remote.remote_connection] DEBUG: POST http://localhost:64283/session/7c26688b1c8a9be128ca383f7546c524/url {"url": "https://www.ptt.cc/bbs/Gossiping/"}
# 2021-10-23 22:35:17 [urllib3.connectionpool] DEBUG: http://localhost:64283 "POST /session/7c26688b1c8a9be128ca383f7546c524/url HTTP/1.1" 200 14
# 2021-10-23 22:35:17 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2021-10-23 22:35:17 [py.warnings] WARNING: <ipython-input-38-e2484363da4d>:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   btn=driver.find_element_by_name('yes')
#
# 2021-10-23 22:35:17 [selenium.webdriver.remote.remote_connection] DEBUG: POST http://localhost:64283/session/7c26688b1c8a9be128ca383f7546c524/element {"using": "css selector", "value": "[name=\"yes\"]"}
# 2021-10-23 22:35:17 [urllib3.connectionpool] DEBUG: http://localhost:64283 "POST /session/7c26688b1c8a9be128ca383f7546c524/element HTTP/1.1" 200 88
# 2021-10-23 22:35:17 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2021-10-23 22:35:17 [selenium.webdriver.remote.remote_connection] DEBUG: GET http://localhost:64283/session/7c26688b1c8a9be128ca383f7546c524/screenshot {}
# 2021-10-23 22:35:17 [urllib3.connectionpool] DEBUG: http://localhost:64283 "GET /session/7c26688b1c8a9be128ca383f7546c524/screenshot HTTP/1.1" 200 115664
# 2021-10-23 22:35:17 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2021-10-23 22:35:17 [selenium.webdriver.remote.remote_connection] DEBUG: POST http://localhost:64283/session/7c26688b1c8a9be128ca383f7546c524/element/57a0c037-214e-41d1-b642-eb84f93ebfd6/click {"id": "57a0c037-214e-41d1-b642-eb84f93ebfd6"}
# 2021-10-23 22:35:18 [urllib3.connectionpool] DEBUG: http://localhost:64283 "POST /session/7c26688b1c8a9be128ca383f7546c524/element/57a0c037-214e-41d1-b642-eb84f93ebfd6/click HTTP/1.1" 200 14
# 2021-10-23 22:35:18 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2021-10-23 22:35:18 [selenium.webdriver.remote.remote_connection] DEBUG: GET http://localhost:64283/session/7c26688b1c8a9be128ca383f7546c524/screenshot {}
# 2021-10-23 22:35:18 [urllib3.connectionpool] DEBUG: http://localhost:64283 "GET /session/7c26688b1c8a9be128ca383f7546c524/screenshot HTTP/1.1" 200 175772
# 2021-10-23 22:35:18 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2021-10-23 22:35:18 [selenium.webdriver.remote.remote_connection] DEBUG: GET http://localhost:64283/session/7c26688b1c8a9be128ca383f7546c524/source {}
# 2021-10-23 22:35:18 [urllib3.connectionpool] DEBUG: http://localhost:64283 "GET /session/7c26688b1c8a9be128ca383f7546c524/source HTTP/1.1" 200 15903
# 2021-10-23 22:35:18 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# <html><head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>›</span>
# 		<a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
#
# <div id="main-container">
# 	<div id="action-bar-container">
# 		<div class="action-bar">
# 			<div class="btn-group btn-group-dir">
# 				<a class="btn selected" href="/bbs/Gossiping/index.html">看板</a>
# 				<a class="btn" href="/man/Gossiping/index.html">精華區</a>
# 			</div>
# 			<div class="btn-group btn-group-paging">
# 				<a class="btn wide" href="/bbs/Gossiping/index1.html">最舊</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index39537.html">‹ 上頁</a>
# 				<a class="btn wide disabled">下頁 ›</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index.html">最新</a>
# 			</div>
# 		</div>
# 	</div>
#
# 	<div class="r-list-container action-bar-margin bbs-screen">
# 		<div class="search-bar">
# 			<form type="get" action="search" id="search-bar">
# 				<input class="query" type="text" name="q" value="" placeholder="搜尋文章⋯">
# 			</form>
# 		</div>
#
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">4</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1634999505.A.F6D.html">[問卦] 如何抵制大甲媽？</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">ak47good</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">⋯</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E5%A6%82%E4%BD%95%E6%8A%B5%E5%88%B6%E5%A4%A7%E7%94%B2%E5%AA%BD%EF%BC%9F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aak47good">搜尋看板內 ak47good 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">10/23</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1634999526.A.9F2.html">[問卦] 我有大潤發跟全聯的會員卡,怎麼辦???</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">AAApower</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">⋯</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E6%88%91%E6%9C%89%E5%A4%A7%E6%BD%A4%E7%99%BC%E8%B7%9F%E5%85%A8%E8%81%AF%E7%9A%84%E6%9C%83%E5%93%A1%E5%8D%A1%2C%E6%80%8E%E9%BA%BC%E8%BE%A6%3F%3F%3F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3AAAApower">搜尋看板內 AAApower 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">10/23</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">1</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1634999561.A.08A.html">[問卦] 是不是有很多沒吃過鹹豆漿的人</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">dasuininder</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">⋯</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E6%98%AF%E4%B8%8D%E6%98%AF%E6%9C%89%E5%BE%88%E5%A4%9A%E6%B2%92%E5%90%83%E9%81%8E%E9%B9%B9%E8%B1%86%E6%BC%BF%E7%9A%84%E4%BA%BA">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Adasuininder">搜尋看板內 dasuininder 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">10/23</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1634999585.A.F47.html">Re: [新聞] 3Q被罷免 高閔琳：徹底檢討現行罷免門檻</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author