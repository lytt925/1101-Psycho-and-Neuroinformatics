# %% [markdown]
# # Psychoinformatics - Week 4 (Exercises)
# by yourname (your email)

# %% [markdown]
# ## 1 Analyze what videos go viral? (8 points)

# %% [markdown]
# Please use <a href="https://developers.google.com/youtube/v3/code_samples/python">YouTube APIs</a> to carry out a data-driven or hypothesis-driven microstudy about the characteristics of viral videos.
#
# You need to present, here in this notebook, AT LEAST two <b>statistical</b> figures or tables as supporting evidence for your arguments. Each of these figures/tables deserves 4 points.

# %%
key = 'AIzaSyAUzMOVN4RV3Opf0Z9wIMGLADcXtpVUPpk'
def youtube_mostPopular():

    youtube = build('youtube','v3',developerKey=key)
    result = youtube.videos().list(
    part='snippet,statistics',
    chart='mostPopular',
    regionCode='TW',maxResults=50).execute()

    title = []
    viewCount = []
    likeCount = []
    dislikeCount = []
    commentCount = []
    tags = []
    categoryId = []
    
    
    for search_result in result.get("items", []):
        if search_result["kind"] == "youtube#video":
            title.append(search_result['snippet']['title'])
            viewCount.append(search_result['statistics']['viewCount'])
            if 'likeCount' in search_result['statistics'].keys():  
                likeCount.append(int(search_result['statistics']['likeCount']))
            else:
                likeCount.append(None)
            if 'dislikeCount' in search_result['statistics'].keys():  
                dislikeCount.append(int(search_result['statistics']['dislikeCount']))
            else:
                dislikeCount.append(None)
            if 'commentCount' in search_result['statistics'].keys():
                commentCount.append(int(search_result['statistics']['commentCount']))
            else:
                commentCount.append(None)
            if 'tags' in search_result['snippet'].keys():
                tags.append(search_result['snippet']['tags'])
            else:
                tags.append([])
            categoryId.append(search_result['snippet']['categoryId'])

                

    youtube_dict = {'title':title,'viewCount':viewCount,'likeCount':likeCount,'dislikeCount':dislikeCount,'commentCount':commentCount,'tags': tags,'categoryId':categoryId}
    
    return youtube_dict

# %%
# Please carry out your analysis here
import pandas as pd
test = youtube_mostPopular()
df = pd.DataFrame(data=test)

# %% [markdown]
# # Hypothesis 1:
# 越熱門的影片曝光率比較高，更容易引來頻道訂閱者以外的觀眾收看，因此更容易接觸到非同溫層的人。
# 因此我猜想排名越前面的影片可能因此dislike相對於like的比例(dislikeCount/likeCount)會相對較高。
# 之後採用Kendall's tau來作為相關的指標

# %%
df['dislikeRatio'] = df['dislikeCount']/(df['dislikeCount']+df['likeCount'])
df["index"] = np.arange(len(df), 0,-1) # 數字越大為越熱門的影片
df.dropna(inplace = True)
df
# Out:
#                                                 title  viewCount  likeCount  \
# 0   聽見玻璃心碎的聲音... 黃明志 Ft.陳芳語【玻璃心】@鬼才做音樂 2021 Ghosician   13309114     585013
# 1   被「換臉」成謎片主角只能自認倒霉？Deep Fake 的傷害有多大？｜志祺七七 ft. 魚乾...     455584      22971
# 2       【#狗屎寫手】ＱＱㄋㄟㄋㄟ的出處｜#Chill革命 現場版｜ @喬瑟夫 ChillSeph     340101      14967
# 3                   請不要對號入座... 黃明志 Ft.陳芳語【玻璃心】MV 製作花絮     590624      39731
# 4   【正常發揮PiMW】降半旗"今天公祭" 嗨唱歌"3Q忘記“罷前之夜! 網集氣"送陳柏惟回高雄...     195889      26475
# 5         SEVENTEEN (세븐틴) 'Rock with you' Official MV    9026540     792186
# 6   陳柏惟總統級造勢.警犬巡邏! 46死陳其邁不辭職只說不停止檢討! 公祭降半旗 蔡英文只停3分...     235767      14702
# 42  [Video Game (Industry), Gaming Talk Shows, Pla...         20
# 43  [盧廣仲, Crowd Lu, 自我的介紹, in peace, MV, Teaser, 卢...         10
# 44  [BackKooYoung, JangJuHee, JoAYoung, LimHanByul...         24
# 45  [ショパンコンクール, 2021, chopin, competition, institu...         10
# 46  [Action, Andy Serkis, Batman, Batman v Superma...          1
# 47  [玻璃心, fragile, 小粉紅, Kimberley Chen, 陳芳語, Kimbe...         24
# 48  [豪記, 上豪, 豪聲, MV首播, 台語歌, 台語新歌, 台灣流行樂, 福建, 閩南語, ...         10
# 49  [地球黃金線, 黃金地球線, 重機, 超跑, 跑車, 汽車保養, 休旅車, 賞車, 試駕, ...          2
#
#     dislikeRatio  index
# 0       0.024401     50
# 1       0.018962     49
# 2       0.006901     48
# 3       0.011495     47
# 4       0.009688     46
# 5       0.003418     45
# 6       0.016523     44
# 7       0.032018     43
# 8       0.007490     42
# 9       0.047007     41
# 10      0.047019     40
# 11      0.006818     39
# 12      0.008676     38
# 13      0.030368     37
# 14      0.009145     36
# 15      0.067834     35
# 16      0.027632     34
# 17      0.005115     33
# 18      0.005155     32
# 19      0.127023     31
# 20      0.013095     30
# 21      0.020960     29
# 22      0.017424     28
# 23      0.004278     27
# 24      0.029838     26
# 25      0.023558     25
# 26      0.075122     24
# 27      0.011505     23
# 28      0.143875     22
# 29      0.030898     21
# 30      0.005604     20
# 31      0.018444     19
# 32      0.041420     18
# 33      0.025443     17
# 34      0.006635     16
# 35      0.011327     15
# 36      0.027027     14
# 37      0.019381     13
# 38      0.010196     12
# 39      0.011489     11
# 40      0.005147     10
# 41      0.004840      9
# 42      0.016228      8
# 43      0.004607      7
# 44      0.007548      6
# 45      0.036641      5
# 46      0.028486      4
# 47      0.022915      3
# 48      0.026667      2
# 49      0.044934      1

# %%
import scipy.stats as stats
tau, p_value = stats.kendalltau(df['index'],df['dislikeRatio'])
print(tau)
print(p_value)
print(df.plot.scatter('index','dislikeRatio',title = "Dislike Ratio between videos"))
# Out:
# -0.02530612244897959
# 0.7953956085344035
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# ## Kendall's tau 約為 -0.08, p-value約0.4
# 由統計結果以及散布圖可知倒讚的比例跟發燒影片沒什麼相關，但也有可能是因為只獲得發燒影片的資料，沒有分析非發燒影片的資料，樣本性質太相近因此無法確定倒讚比例跟熱門程度的關連。

# %% [markdown]
# # 會上發燒的大多數是什麼類型的影片？
# 我認為應該主要應該是娛樂性質的影片偏多

# %%
categoryDict = {
'2':'Autos & Vehicles',
'1' :'Film & Animation',
'10':'Music',
'15':'Pets & Animals',
'17':'Sports',
'18':'Short Movies',
'19':'Travel & Events',
'20':'Gaming',
'21':'Videoblogging',
'22':'People & Blogs',
'23':'Comedy',
'24':'Entertainment',
'25':'News & Politics',
'26':'Howto & Style',
'27':'Education',
'28':'Science & Technology',
'29':'Nonprofits & Activism',
'30':'Movies',
'31':'Anime/Animation',
'32':'Action/Adventure',
'33':'Classics',
'34':'Comedy',
'35':'Documentary',
'36':'Drama',
'37':'Family',
'38':'Foreign',
'39':'Horror',
'40':'Sci-Fi/Fantasy',
'41':'Thriller',
'42':'Shorts',
'43':'Shows',
'44':'Trailers'
}

df['categoryId'] = df['categoryId'].apply(lambda x: categoryDict[x])

# %%
df2 = pd.DataFrame()
df2['categoryCounts'] = pd.DataFrame(df['categoryId'].value_counts())
display(df2)
display(df[['title','categoryId']])
# Out:
#                   categoryCounts
# News & Politics               16
# Music                         10
# Entertainment                 10
# People & Blogs                 6
# Film & Animation               2
# Pets & Animals                 2
# Education                      1
# Comedy                         1
# Gaming                         1
# Autos & Vehicles               1
#                                                 title        categoryId
# 0   聽見玻璃心碎的聲音... 黃明志 Ft.陳芳語【玻璃心】@鬼才做音樂 2021 Ghosician             Music
# 1   被「換臉」成謎片主角只能自認倒霉？Deep Fake 的傷害有多大？｜志祺七七 ft. 魚乾...    People & Blogs
# 2       【#狗屎寫手】ＱＱㄋㄟㄋㄟ的出處｜#Chill革命 現場版｜ @喬瑟夫 ChillSeph     Entertainment
# 3                   請不要對號入座... 黃明志 Ft.陳芳語【玻璃心】MV 製作花絮     Entertainment
# 4   【正常發揮PiMW】降半旗"今天公祭" 嗨唱歌"3Q忘記“罷前之夜! 網集氣"送陳柏惟回高雄...   News & Politics
# 5         SEVENTEEN (세븐틴) 'Rock with you' Official MV             Music
# 6   陳柏惟總統級造勢.警犬巡邏! 46死陳其邁不辭職只說不停止檢討! 公祭降半旗 蔡英文只停3分...   News & Politics
# 7   #玩很大七週年感謝祭 關於KID涉及在大馬路上跟鬼鬼吵架的重要聲明！開玩笑的啦～我們為了玩粉...     Entertainment
# 8   【正常發揮PiMW】綠議員逼"不念四個堅持就道歉"! 柯暴怒嗆:"網軍治國是民主自由?" 陳...   News & Politics
# 9       【央視一分鐘】小玉涉「換臉」不雅片遭逮 黃明志.陳芳語MV《玻璃心》狠辱華｜眼球中央電視台   News & Politics
# 10      簡舒培逼覆誦蔡英文四個堅持！柯文哲爆氣怒吼「廢話不想唸」　反噹一句話秒讓她語塞｜中時新聞網   News & Politics
# 11       「你總是希望不斷前進，但感受是得停下來的。」- 這集突然變成 #謝盈萱 的諮商實境節目？         Education
# 12  【中天#互動LIVE】歡送3Q 罷免陳柏惟! 找回光榮 贏回台中 人民作主的力量!  重量級...   News & Politics
# 13               小粉紅怒炸！〈玻璃心〉觀看暴衝600萬 黃明志再酸：留言符合主題｜鏡週刊   News & Politics
# 14                     [MV] IU(아이유) _ strawberry moon     Entertainment
# 15     66歲高向鵬搶救第7天，兒子痛哭再曝病況！昏迷原因終於瞞不住！#高向鵬 #方怡萍 #茶娛飯後  Film & Animation
# 16  "台灣熱炒"飄香曼哈頓！思鄉遊子將"板凳.酒杯"帶入紐約 熱炒店充滿"台味"...開店一年登...   News & Politics
# 17                                 【豆漿&俊榮】 洗貓真的好煩阿阿阿阿    Pets & Animals
# 18   TRASH 《離開台北 LEAVING TAIPEI》 Official Music Video             Music
# 19                       小玉「換臉」後製A片牟利千萬 訊後以50萬元交保｜鏡週刊     Entertainment
# 20  DJ Snake, Ozuna, Megan Thee Stallion, LISA of ...             Music
# 21  獨家專訪｜陳芳語震碎強國「玻璃心」　親回挨轟難相處、搶賺人民幣黑歷史 | 台灣新聞 Taiw...   News & Politics
# 22  這群人 TGOP │那些爸媽曾經對你說過的謊 Lies Your Parents Told You     Entertainment
