# %% [markdown]
# # Psychoinformatics - Week 4 (Examples)
# by Tsung-Ren (Tren) Huang (trhuang@g.ntu.edu.tw)

# %% [markdown]
# ## 0 Package Installation

# %%
# !pip install dcard-spider facebook-sdk tweepy
# !pip install oauth2 google-api-python-client
# !pip install --upgrade oauth2client

# %% [markdown]
# ## 1 Dcard
# Check out <a href=https://blog.jiatool.com/posts/dcard_api_v2/>this webpage</a> for more details about the Dcard APIs.

# %%
import urllib.request,json
u='https://www.dcard.tw/_api/posts/226048661'
r=urllib.request.Request(u,headers={'User-Agent':''})
data=urllib.request.urlopen(r).read()
j_data=json.loads(data)
print(type(j_data))
print(j_data['media'][0]['url'])
for key in j_data.keys():
  print(key,':',j_data[key])
# Out:
# <class 'dict'>
# https://i.imgur.com/lof9lya.jpg
# id : 226048661
# title : 套房隔音太差，常常聽到鄰居的...
# content : 我租的套房雖然是水泥隔間
# 但因為屋頂是輕鋼架所以隔音還是不太好
# 沒聽過隔壁貓叫春
# 只有一個不知道是隔壁還是樓下的女人很愛半夜唱歌
#
# 某天被她吵得不行
# 一怒之下把wifi熱點的名字改成
#
# https://i.imgur.com/lof9lya.jpg
#
#
#
# 但我晚上其實不一定在家
# 所以後來也忘了這件事
# 名字也沒改回來
#
# 昨天晚上打電動打到一半wifi突然跳出來
# 看到這個名字我當場笑噴
#
# https://i.imgur.com/GQULLhd.jpg
#
# 看來不只我一個人崩潰啊哈哈哈
# 這位鄰居我好想認識你喔～
# excerpt : 我租的套房雖然是水泥隔間，但因為屋頂是輕鋼架所以隔音還是不太好，沒聽過隔壁貓叫春，只有一個不知道是隔壁還是樓下的女人很愛半夜唱歌，某天被她吵得不行，一怒之下把wifi熱點的名字改成，但我晚上其實不一定在家
# anonymousSchool : False
# anonymousDepartment : False
# pinned : False
# forumId : a1aaa6e6-2594-4968-b7dc-e1b14bea96f4
# replyId : None
# createdAt : 2017-03-25T04:32:58.141Z
# updatedAt : 2018-07-26T00:19:20.397Z
# commentCount : 384
# likeCount : 44054
# tags : ['水泥', '一怒之下', '叫春', '跳出來', '熱點', '打電動', '聽過', '隔音', '鋼架', '隔壁', '名字', '套房', '不一定', '改回來', '屋頂', '吵得', 'wifi', '隔間', '...', '是輕', '件事']
# topics : []
# supportedReactions : None
# withNickname : False
# reportReason :
# hiddenByAuthor : False
# meta : {}
# forumName : 有趣
# forumAlias : funny
# nsfw : False
# school : 國立臺北大學
# department : 社會工作學系
# replyTitle : None
# gender : F
# personaSubscriptable : True
# reactions : [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 44046}, {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 8}]
# hidden : False
# customStyle : None
# isSuspiciousAccount : False
# isModerator : False
# layout : classic
# spoilerAlert : False
# totalCommentCount : 384
# withImages : True
# withVideos : False
# media : [{'url': 'https://i.imgur.com/lof9lya.jpg'}, {'url': 'https://i.imgur.com/GQULLhd.jpg'}]
# reportReasonText :
# mediaMeta : []
# excerptComments : []
# edited : False
# postAvatar :
# activityAvatar :
# verifiedBadge : False
# memberType :

# %%
from dcard import Dcard
def filter(metas):
 return [m for m in metas if m['likeCount'] >= 50]
 #return [m for m in metas if "女友" in m['topics']]

d=Dcard()
f=d.forums('photography') #攝影版
m=f.get_metas(num=500,callback=filter) #list
p=d.posts(m).get(comments=False)
r=p.parse_resources() #list: try r[0][1]
done,fails=p.download(r)
print('Got %d pics' % done if len(fails)==0 else 'Error!')
# Out:
# Got 0 pics

# %%
u='https://www.dcard.tw/service/api/v2/forums/photography/posts?limit=100'
r=urllib.request.Request(u,headers={'User-Agent':''})
data=urllib.request.urlopen(r).read()
j_data=json.loads(data.decode('utf-8'))
c=0
for post in j_data:
    if('貓' in post['topics']):
        print(post['id'])
        for i in range(len(post['media'])):
            url=post['media'][i]['url']
            urllib.request.urlretrieve(url,'./downloads/'+str(post['id'])+'_'+url.rsplit('/', 1)[-1])
# Out:
# 237239296
# 237236942
# 237235658
# 237227980
# 237208446
# 237202059

# %% [markdown]
# ## Facebook

# %%
import json
def show(j_in):
  print(json.dumps(j_in,ensure_ascii=False,indent=2))

import facebook
token='EAAYAOVZA9YWQBADX7gnvTQoQ5e5SxMmTqwVtMP4EcM4AvK4hcd5zduK20gtfqJEzVWlvkMIJQ8wwBC8ZB10wMbmV68vbpbRoR4dRiFVsEpVGKpwzutXT1RoYSOAyTmgJ6pb7d86ZBwWeevTk6WmHzLKlvR2v8wV6S0Pj2oeuLmOZBYkqNYLVwoTJoF1XRhuQ2GLCIsIBZBQZDZD'  # replaced by your access token
graph=facebook.GraphAPI(token)
show(graph.get_object('me',fields='id,name,email,age_range,posts'))
show(graph.get_connections('me','friends'))
#graph.put_object('me','feed',message='Hello from class!')
# see https://stackoverflow.com/questions/52353828/posting-to-facebook-with-python-and-graph-api-permissions-issue
# Out:
# {
#   "id": "10158570278459750",
#   "name": "Tren Huang",
#   "email": "tren.huang@gmail.com",
#   "age_range": {
#     "min": 21
#   },
#   "posts": {
#     "data": [
#       {
#         "created_time": "2021-10-14T07:10:16+0000",
#         "message": "我剛剛一邊聽著林隆璇的歌，一邊就收到他的按讚通知。這其中一定有什麼心電感應~",
#         "id": "10158570278459750_10160202174254750"
#       },
#       {
#         "created_time": "2021-09-10T06:57:06+0000",
#         "message": "《秘密》當你真心渴望專心寫論文，全世界都會聯合起來阻撓你~\n\n#宇宙神秘的力量",
#         "id": "10158570278459750_10160138947764750"
#       },
#       {
#         "created_time": "2021-08-01T18:34:12+0000",
#         "message": "看完小戴比賽後，就乖乖地去改論文了... \n\n結果... 審查委員可能也在蹭奧運熱度，推薦了這篇12位奧運金牌選手的心理素質/韌性研究: \n\nFletcher, D., & Sarkar, M. (2012). A grounded theory of psychological resilience in Olympic champions. Psychology of Sport and Exercise, 13(5), 669-678.\n\n結論在附圖，大意在闡明心理素質/韌性的功能：「正面地去看待挫敗與調整自己的負面想法/情緒，使壓力能轉化成進步或得勝的動力」，以及其正向滋養因子：正向的性格、(求勝的)動機、(得勝的)信心、專注(在自己與過程)、感受到的社會支持。以下是幾段訪談範例：\n\n[功能：調整自己的負面想法/情緒]\nI’ve never ever been more nervous than before the final. And one of the things I used [was] visualization . I saw one of the co-favorites take a start and he appeared to fly round the first bend. And so my heart hit my throat. Then I thought, ‘oh my God, I’ve got to run faster than that?’ And I recognized how unhelpful that negative thought was so . I just thought ‘get a grip’ and I thought ‘when have you felt really powerful and flowing?’\n-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-\n我從未像決賽前這麼緊張。在我腦中有一幕是我的對手起跑後迅即飛過第一個彎道。這讓我心臟快要跳出喉嚨了，且接續的想法是：「天啊，我得跑比得比那樣快？」不過，我在意識到這想法是負面且無濟於事後，便轉念告訴自己：「鎮定，過去的你會在什麼時候感受到無比的強大與流暢？」\n\n[功能：轉化挫敗為成功的動力]\nThere was a [cup] I just missed out on, and that was the first time I thought to myself ‘I don’t want to do this again . I don’t want to miss out on these events’ and started training harder and working harder.\n-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-\n我錯失了一次[世界盃]，且那是第一次我告訴自己：「我不要再這樣。我不想再錯失這些賽事。」然後我開始訓練得更認真，更努力表現。\n\n不過今晚... 我想來點：\n\n[滋養因子：感受到的社會支持]\nI’ve got injured, I’ve not got selected, all those sort of things where it’s not gone right . But . they [one’s parents] talk it through with you. My mum especially would talk it through and say ‘What are you going to do about it?’ They didn’t judge me and say, ‘You’re doing this wrong’ or ‘you’re doing that right’, they just provided me with the support that you need and a sounding board to express myself.\n-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-\n我受傷了，我沒被選上，所有這些事都很不順。但我父母會和我講開這些。我媽特別如此，且會問：「你打算怎麼辦？」他們不會批評式地講出：「你做錯了」 或 「你做對了」。他們只是給予我正需的支持並在我表達時給予我傾聽與建議。\n\n猶記MOOC名師 黃朝曦 對小時候的我講過一句意味深長的話：「真正努力過的人沒有不在乎結果的。」\n\n對已經這麼努力的台灣選手，能不能少點責難，多點溫暖與支持？這樣我們才能有心理素質更強大的國手，在三年後再次成就自己成就台灣！ \n\n#大眾也該知道的運動心理學 #國手心理韌性你我都推了一把",
#         "id": "10158570278459750_10160060609644750"
#       },
#       {
#         "created_time": "2021-07-29T03:43:25+0000",
#         "message": "I acknowledge your acknowledgements.\n\n#眾人皆醉沒有人醒 #英文好難",
#         "id": "10158570278459750_10160052800489750"
#       },
#       {
#         "created_time": "2021-07-08T06:22:39+0000",
#         "message": "有沒有7/12之後是2+2.2361i級的八卦? 就是號稱標準(norm)是3級, 但實質部分只有2級?\n\na=2+2.2361i; norm(a) = 3.0000\n\n#複變學得好一輩子沒煩惱",
#         "id": "10158570278459750_10160007084659750"
#       },
#       {
#         "created_time": "2021-03-23T03:47:13+0000",
#         "message": "米國真是太危險惹~\n\nhttps://en.wikipedia.org/wiki/List_of_mass_shootings_in_the_United_States_in_2019\n\nhttps://en.wikipedia.org/wiki/List_of_mass_shootings_in_the_United_States_in_2020\n\nhttps://en.wikipedia.org/wiki/List_of_mass_shootings_in_the_United_States_in_2021",
#         "id": "10158570278459750_10159745511144750"
#       },
#       {
#         "created_time": "2021-03-11T13:15:22+0000",
#         "message": "救救台大AI中心 XD",
#         "id": "10158570278459750_10159713128904750"
#       },
#       {
#         "created_time": "2021-01-15T09:38:47+0000",
#         "message": "程式真的做不出來該怎麼辦？\n\n#文章其實是寫給PM看的 #研究也適用 #以下開放各種抱怨",
#         "id": "10158570278459750_10159546007274750"
#       },
#       {
#         "created_time": "2021-01-11T09:14:10+0000",
#         "message": "剛畢業因故沒辦法留學，或是年後想換工作嗎？  \n\n誠徵【網站前/後端全職/兼職工程師】  \n\n工作主題: 建置「臺灣社會科學腦造影暨行為研究資料庫」網站  \n\n工作時期: 2021年2月~2022年7月至少18個月  \n\n工作地點: 台大心理學系 / 台大永齡生醫工程館 / 在家  \n\n工作薪資: 台大研究助理標準薪資(https://ppt.cc/fGQjHx) + 15%彈性加給; 享勞健保與其他校內人員福利  \n\n工作資格: [前端] React (+Hooks), CSS, & RWD; [後端] Flask, MySQL, & MongoDB (因需整合舊程式，熟悉PHP者為佳)\n\n工作內容: 與技術專案經理(熟悉前後端與伺服器)及前/後端人員共三人團隊，在科技部前瞻司/人文司與台大/政大/成大三校腦造影中心的指導下，於國家高速網路與計算中心的雲端上建置一全國性之資料庫查詢/共享網站。網站已有部分規格/程式碼，但仍有其它全新機制/內容待討論/開發。\n\n本工作適合對基礎網站開發已有經驗、想要挑戰開發進階/大型網站、有意建立代表作/作品集、或是對神經資訊學(Neuroinformatics)有興趣的夥伴。歡迎對神經科學、行為科學、AI/機器人的整合有興趣者加入「模型建構與資訊學實驗室」的大家庭!\n\n意者請email聯絡黃從仁老師(trhuang@ntu.edu.tw)，並附上個人中文或英文簡歷(CV)與自我推薦信(Cover Letter)。謝謝！",
#         "id": "10158570278459750_10159536084364750"
#       },
#       {
#         "created_time": "2020-12-30T07:37:44+0000",
#         "message": "大家狂熬夜趕出來的遊戲今天終於要上線公測了!\n\n我想 ，這種極度痛苦後，看到成品的滿足感，大概就是正向心理學中所謂的真正幸福(eudaimonia)吧!?\n\n#感謝團隊",
#         "id": "10158570278459750_10159495408909750"
#       },
#       {
#         "created_time": "2020-10-27T02:25:28+0000",
#         "message": "我小時候以為大學是一個在風和日麗時可以坐在樹下悠閒看書、享受知識的地方...\n\n結果我昨天忙到凌晨三點才睡，而上級和下屬也分別在三點多和四點多因工作來信...\n\n期待周末農閒時能狂補眠，周間只能多來點特大悲咖啡星冰樂壓壓驚...",
#         "id": "10158570278459750_10159324250554750"
#       },
#       {
#         "created_time": "2020-10-15T03:18:30+0000",
#         "message": "十月底遭各種討業績集團連番攻擊\n\n#雖然憨慢還是要快逃",
#         "id": "10158570278459750_10159291167624750"
#       },
#       {
#         "created_time": "2020-10-08T01:36:06+0000",
#         "message": "好書推薦：Mindf*ck 心智操控【劍橋分析技術大公開】\n\n根據2020年初的統計資料，臺灣有近八成五的上網人口，而這其中約有九成是臉書（ Facebook ）的使用者。我們打開臉書，除了好奇地瀏覽舊識與新交的近況，也不忘抒發心情並記錄下自己的生活點滴與這些朋友們分享。較不在乎個人隱私的使用者，除了在個人的介紹頁面中如實地填入如性別、年紀、居住地等基本資料外，也無所顧忌地留下如宗教信仰、政治立場、與戀愛性向等進階資訊。相反地，較在意維護個人隱私的使用者，時常在臉書的使用上遵循著四不一沒有的原則：非必要不填個人資料、不主動張貼留言、不分享影音照片、不與他人有過多互動，於是逐漸沒有朋友……\n\n「我po這些東西本來就是要給朋友看的啊！」，您義正詞嚴。問題是：有些內容您的朋友不想看（例如一早刷牙流血的照片），且能看到的不一定是您的朋友（例如您在臉書資料科學團隊工作的情敵）。本書的作者克里斯多福·懷利 (Christopher Wylie) ，具有「劍橋分析」（Cambridge Analytica）公司的多個頭銜──共同創辦人、前研究總監、以及吹哨者。懷利在本書中用自傳式的口吻，娓娓道來他們的團隊如何利用早期臉書敞開的資安大門，大量地去搜刮臉書上數億個使用者的資訊，並進一步地將這些臉書與其他資料來源做串接。當他們恣意地去檢視素昧平生的臉書使用者房子的衛星照片、家人照片、以及各種癖好時，您與我可能都是他們所輕蔑嘲笑的那個怪胎。\n\n「那又怎麼樣？」，您一臉不屑。《東周列國志》中，文種曾對越王勾踐獻策：「今王志在報吳，必先投其所好，然後得制其命」。歷史的教訓是 ：個人的特質、價值、偏好、或心中最深層的恐懼一旦被精準掌握，輕則個人被利用，重則導致國破家亡。懷利在本書中列舉了許多這種掌控人心，操弄各國選舉的範例。不若過去的政治宣傳活動般只依照性別、年紀、居住地等人口學資料來將選民分類，他們透過臉書上的動態消息、追蹤、按讚、分享等數位足跡（digital footprints）來對臉書的使用者做心理剖繪（psychological profiling），讓政治宣傳能夠見人說人話，見鬼說鬼話，人鬼盡歡。\n\n「就像是谷歌（Google）與亞馬遜（Amazon）所做的個人化廣告推薦那樣嗎？」，您好奇。不，沒那麼簡單！他們會在臉書鎖定欲操弄的對象（如其客戶欲殲滅的對手陣營或文化團體）來創建粉絲專頁，在吸引心理特質與政治/文化理念相似的使用者後，首先於粉專中測試怎樣的話術或假消息最能夠煽動這個同溫層， 之後再把有效的謠言透過暗樁在線上或線下的相關團體中做大規模的傳播，達到心戰目的。這裡的對手陣營可以像是政治組織或公司行號，文化團體可以像是女性主義或是特定宗教等各種社團。\n\n作者聲稱2013年才建立的「劍橋分析」公司便是透過如此的精準投放（microtargeting）來影響2016年的英國脫歐公投以及當年的美國總統大選結果等世界重大歷史事件。和實驗室的心理學實驗不同，這些真實生活中的心智操控，除了\"受控者\"並非在知情同意（informed consent）的情況下被操弄，也無徹底不受到假新聞污染的\"控制組\"可供比較。因此，雖然書中所提的選舉結果對「劍橋分析」來說可謂是稱心如意，但科學上不能推斷這些操弄是否真有效果或是有多少效果。換句話說，這些書中所提的選舉結果，有可能真是「劍橋分析」的豐功偉業，也有可能僅是歷史上的因緣巧合。不過即便是後者，本書所介紹的各種心理剖繪與心智操控技術，的確也都有其學術研究的基礎，而「劍橋分析」所濫用這些技術的方式，也令人大開眼界並有所省思。\n\n水能載舟，亦能覆舟。 整個懷利人生上半場的故事中，最諷刺的莫過於他本來懷抱著理想，想用科技和創新來改善政治和世界，最後卻淪為別人的政治工具在世界各處鼓動仇恨和對立；而懷利原本在他一手打造的「劍橋分析」公司中透過大數據監控他人，卻在他踢爆公司內情後反過頭來受到各方奪命式的監控；到最後，這個科技頑童不得不盡量遠離網路、電腦、與手機，反璞歸真地過著低科技的生活。由此可見，科技本身是中性的，其影響是好是壞端看是落在好人或壞人手中。當我們一方面享受著網路與社群媒體所帶來的便利，大方地送出個資來換取個人化服務的同時，我們也應當意識到：在世界的某個暗黑一隅，一台電腦之前，可能有個像上帝的老大哥時時刻刻地在瞪大雙眼看顧著我們，而且更重要的是：一切都在他的掌控之中……\n\n「我彷彿看到了這位老大哥」，您若有所感。\n\n等等！您不會正是作者口中那個疑神疑鬼而容易相信陰謀論的高神經質者吧！？",
#         "id": "10158570278459750_10159270622199750"
#       },
#       {
#         "created_time": "2020-09-23T02:32:24+0000",
#         "message": "有時會和一群chatbots聊到哭笑不得",
#         "id": "10158570278459750_10159226938739750"
#       },
#       {
#         "created_time": "2020-09-06T14:22:00+0000",
#         "message": "海水退潮了就知道我有穿褲子!\n\n被懷疑做不出來的計畫我還是完成了喔~\n\n#GetThingsDone #MakeThingsHappen",
#         "id": "10158570278459750_10159181037414750"
#       },
#       {
#         "created_time": "2020-07-29T16:14:29+0000",
#         "message": "【手把手的教與學】\n\n看了學生的程式，大致是對的，但在小細節上出了一些錯誤，導致最後的研究結論仍是錯的。不過此時所浮現的倒是正面而不是負面的情緒～\n\n該怎麼說呢？學生的情況像是拉筋或做瑜珈，初學者模仿老師的外型動作，但因為沒有透徹了解一個姿勢的內涵和目的，姿勢常常沒有掌握要領拉到內在該拉的東西。不過這也不是學生的錯，而是一個學習技藝、掌握技藝的自然過程，需要老師手把手地耐心修正。\n\n「養兒方知父母恩」，當了老師才知道原來要把學生一路捏捏捏，捏到成熟其實頗費心力。於是我開始感念起不嫌棄我資質駑鈍，仍願意幫我調整各種觀念/動作的老師們......\n\n我相信有一天我一定能不負老師們的指導，代表傳武界打敗徐曉冬! (喂! 跑錯棚?)\n\n#師徒制的浪漫",
#         "id": "10158570278459750_10159069660009750"
#       },
#       {
#         "created_time": "2020-07-16T05:29:13+0000",
#         "message": "萬事問臉友:\n\n有一隻鳥跟著我們的車回家了。牠可能是受傷了，現在停在電箱上面休息。牠這樣不吃不喝下去也不是辦法，請問該怎麼處理?",
#         "id": "10158570278459750_10159028550044750"
#       },
#       {
#         "created_time": "2020-06-30T05:27:28+0000",
#         "message": "萬事問臉書2: 為何這個KNN比SVR更神?\n-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-\nimport numpy as np\nfrom sklearn import model_selection,neighbors\nfrom scipy.stats import pearsonr\nX=np.zeros((200,1))\nY=np.random.rand(200)\nYp=model_selection.cross_val_predict(neighbors.KNeighborsRegressor(199),X,Y,cv=200) # leave-1-out \nprint('correlation:',pearsonr(Y,Yp))\n-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-\ncorrelation: (-1.0, 0.0)",
#         "id": "10158570278459750_10158974763514750"
#       },
#       {
#         "created_time": "2020-06-30T05:13:16+0000",
#         "message": "萬事問臉書: 為何這個SVR這麼神?\n-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-\nimport numpy as np\nfrom sklearn import model_selection,svm\nfrom scipy.stats import pearsonr\nX=np.zeros((200,1)) # 200 samples of zeros \nY=np.random.rand(200) # random continuous Y\nYp=model_selection.cross_val_predict(svm.SVR(),X,Y,cv=200) # leave-1-out \nprint('correlation:',pearsonr(Y,Yp)) \n-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-\ncorrelation: (-0.9276546220323998, 1.2158583522119985e-86)",
#         "id": "10158570278459750_10158974739739750"
#       },
#       {
#         "created_time": "2020-06-28T10:11:48+0000",
#         "message": "關於某科科部各種計畫審查，我想說的是……. \n\n如果我們能不吝給學生鼓勵，為何不能給同行溫暖而總要受囿於角色內行為砍個彼此血流如注?\n\n#冤冤相報何時了處處蚊子咬 #把愛傳出去TrenCanHelp #科科",
#         "id": "10158570278459750_10158968799149750"
#       },
#       {
#         "created_time": "2020-06-28T09:52:45+0000",
#         "message": "TCPSR八月起會在台北進行八次實體活動，因此想徵求一位台大學生擔任助理，協助社群活動與媒體經營。因為其任務以經營網路社群為主，不需要每場都要到現場，主要工作是事前發佈活動資訊 與事後在各大社群平台整理傳播活動紀錄，行政事項主要是核銷外縣市參與老師的交通費及活動餐費。如果對參與TCPSR研讀班課題有興趣的學生，請直接聯絡陳紹慶老師(pmsp96@gmail.com)。\n\n#工商服務",
#         "id": "10158570278459750_10158968759414750"
#       },
#       {
#         "created_time": "2020-05-20T09:31:13+0000",
#         "message": "只是喜歡讀書就一直讀下去，但研究與教學太忙反而沒時間讀閒書。\n\n只是喜歡玩電腦就一直玩下去，但相關的服務工作中都狂被電腦玩。\n\n只是想多點相處的時間就結婚， 但光應付兩寶的教養就已心力交瘁。\n\n所以說婚不能亂結、電腦不能亂玩、書不能亂讀～（飄走）",
#         "id": "10158570278459750_10158825677209750"
#       },
#       {
#         "created_time": "2020-04-26T08:50:54+0000",
#         "message": "和不能睡過夜嬰兒一起生活的結果就是紅茶、抹茶、咖啡、B群輪著喝。\n\n現在此嬰睡很深讓本魯可以偷閒在這裡發廢文，想必晚上兩人又要一起失眠惹~\n\n#蠻牛CanHelp #此嬰IsHelping",
#         "id": "10158570278459750_10158728226349750"
#       },
#       {
#         "created_time": "2020-04-20T15:03:14+0000",
#         "message": "【代徵才】資策會資訊處\n\n1. 職務：程式設計/分析師\n2. 內容：負責整合全會各資訊系統，工作內容包含程式開發與使用者需求發展\n3. 要求技能1(後端)：熟悉C#、net core / MVC\n4. 要求技能2(前端)：jQuery、Angular(二擇一)\n5. 要求技能3(資料庫)：MS-SQL\n6. 其他要求：多益750分以上；略懂資訊系統發展與管理，例如PMP、CMMI…等\n7. PLUS：熟Java、Python\n\n連絡人：資訊處技術服務組組長，莊文德。Mail： peterchuang@iii.org.tw , TEL: 02-6631-8116\n\n#救救資策會 #YouCanHelp",
#         "id": "10158570278459750_10158701300799750"
#       },
#       {
#         "created_time": "2020-03-09T09:53:30+0000",
#         "message": "「確認過眼神」是哪一招？",
#         "id": "10158570278459750_10158532087604750"
#       }
#     ],
#     "paging": {
#       "previous": "https://graph.facebook.com/v4.0/10158570278459750/posts?access_token=EAAYAOVZA9YWQBADX7gnvTQoQ5e5SxMmTqwVtMP4EcM4AvK4hcd5zduK20gtfqJEzVWlvkMIJQ8wwBC8ZB10wMbmV68vbpbRoR4dRiFVsEpVGKpwzutXT1RoYSOAyTmgJ6pb7d86ZBwWeevTk6WmHzLKlvR2v8wV6S0Pj2oeuLmOZBYkqNYLVwoTJoF1XRhuQ2GLCIsIBZBQZDZD&__previous=1&since=1634195416&until&__paging_token=enc_AdCfHvQB7AAoZACSmm1ulThL2ZBn5wblwHFRTpSGrsSFYcVIYaAbngfkXAkjZBEXQvyBZAh969O7xjjFaGTReSdRnkqZAgKJiFulq27UkReZBVIRjf1P5F1VlfIC7WXXfSSchQTU8ZD",
#       "next": "https://graph.facebook.com/v4.0/10158570278459750/posts?access_token=EAAYAOVZA9YWQBADX7gnvTQoQ5e5SxMmTqwVtMP4EcM4AvK4hcd5zduK20gtfqJEzVWlvkMIJQ8wwBC8ZB10wMbmV68vbpbRoR4dRiFVsEpVGKpwzutXT1RoYSOAyTmgJ6pb7d86ZBwWeevTk6WmHzLKlvR2v8wV6S0Pj2oeuLmOZBYkqNYLVwoTJoF1XRhuQ2GLCIsIBZBQZDZD&until=1583747610&since&__paging_token=enc_AdDb7hSUn2rbhjRrlEvBTezvqEVOevZCktfMXjFuCHSSXMiSZA4RPNxMH8V96RWWEDdK8uBTCr2w8cXlctdDgra181M4cCprKAOXBaSDHt6ZAQ8sl82CMCy6frL7vr2qWD9qVEZD&__previous"
#     }
#   }
# }
# {
#   "data": [],
#   "summary": {
#     "total_count": 802
#   }
# }

# %%
import json
def show(j_in):
  print(json.dumps(j_in,ensure_ascii=False,indent=2))

import facebook
token='EAAYAOVZA9YWQBADX7gnvTQoQ5e5SxMmTqwVtMP4EcM4AvK4hcd5zduK20gtfqJEzVWlvkMIJQ8wwBC8ZB10wMbmV68vbpbRoR4dRiFVsEpVGKpwzutXT1RoYSOAyTmgJ6pb7d86ZBwWeevTk6WmHzLKlvR2v8wV6S0Pj2oeuLmOZBYkqNYLVwoTJoF1XRhuQ2GLCIsIBZBQZDZD'  # replaced by your access token
graph=facebook.GraphAPI(token)
show(graph.get_connections('me','friends'))
show(graph.get_object('me',fields='id,name,email,age_range,posts'))
#graph.put_object('me','feed',message='Hello from class!')
# see https://stackoverflow.com/questions/52353828/posting-to-facebook-with-python-and-graph-api-permissions-issue
# Out:
# {
#   "data": [],
#   "summary": {
#     "total_count": 802
#   }
# }
# {
#   "id": "10158570278459750",
#   "name": "Tren Huang",
#   "email": "tren.huang@gmail.com",
#   "age_range": {
#     "min": 21
#   },
#   "posts": {
#     "data": [
#       {
#         "created_time": "2021-10-14T07:10:16+0000",
#         "message": "我剛剛一邊聽著林隆璇的歌，一邊就收到他的按讚通知。這其中一定有什麼心電感應~",
#         "id": "10158570278459750_10160202174254750"
#       },
#       {
#         "created_time": "2021-09-10T06:57:06+0000",
#         "message": "《秘密》當你真心渴望專心寫論文，全世界都會聯合起來阻撓你~\n\n#宇宙神秘的力量",
#         "id": "10158570278459750_10160138947764750"
#       },
#       {
#         "created_time": "2021-08-01T18:34:12+0000",
#         "message": "看完小戴比賽後，就乖乖地去改論文了... \n\n結果... 審查委員可能也在蹭奧運熱度，推薦了這篇12位奧運金牌選手的心理素質/韌性研究: \n\nFletcher, D., & Sarkar, M. (2012). A grounded theory of psychological resilience in Olympic champions. Psychology of Sport and Exercise, 13(5), 669-678.\n\n結論在附圖，大意在闡明心理素質/韌性的功能：「正面地去看待挫敗與調整自己的負面想法/情緒，使壓力能轉化成進步或得勝的動力」，以及其正向滋養因子：正向的性格、(求勝的)動機、(得勝的)信心、專注(在自己與過程)、感受到的社會支持。以下是幾段訪談範例：\n\n[功能：調整自己的負面想法/情緒]\nI’ve never ever been more nervous than before the final. And one of the things I used [was] visualization . I saw one of the co-favorites take a start and he appeared to fly round the first bend. And so my heart hit my throat. Then I thought, ‘oh my God, I’ve got to run faster than that?’ And I recognized how unhelpful that negative thought was so . I just thought ‘get a grip’ and I thought ‘when have you felt really powerful and flowing?’\n-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-\n我從未像決賽前這麼緊張。在我腦中有一幕是我的對手起跑後迅即飛過第一個彎道。這讓我心臟快要跳出喉嚨了，且接續的想法是：「天啊，我得跑比得比那樣快？」不過，我在意識到這想法是負面且無濟於事後，便轉念告訴自己：「鎮定，過去的你會在什麼時候感受到無比的強大與流暢？」\n\n[功能：轉化挫敗為成功的動力]\nThere was a [cup] I just missed out on, and that was the first time I thought to myself ‘I don’t want to do this again . I don’t want to miss out on these events’ and started training harder and working harder.\n-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-\n我錯失了一次[世界盃]，且那是第一次我告訴自己：「我不要再這樣。我不想再錯失這些賽事。」然後我開始訓練得更認真，更努力表現。\n\n不過今晚... 我想來點：\n\n[滋養因子：感受到的社會支持]\nI’ve got injured, I’ve not got selected, all those sort of things where it’s not gone right . But . they [one’s parents] talk it through with you. My mum especially would talk it through and say ‘What are you going to do about it?’ They didn’t judge me and say, ‘You’re doing this wrong’ or ‘you’re doing that right’, they just provided me with the support that you need and a sounding board to express myself.\n-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-\n我受傷了，我沒被選上，所有這些事都很不順。但我父母會和我講開這些。我媽特別如此，且會問：「你打算怎麼辦？」他們不會批評式地講出：「你做錯了」 或 「你做對了」。他們只是給予我正需的支持並在我表達時給予我傾聽與建議。\n\n猶記MOOC名師 黃朝曦 對小時候的我講過一句意味深長的話：「真正努力過的人沒有不在乎結果的。」\n\n對已經這麼努力的台灣選手，能不能少點責難，多點溫暖與支持？這樣我們才能有心理素質更強大的國手，在三年後再次成就自己成就台灣！ \n\n#大眾也該知道的運動心理學 #國手心理韌性你我都推了一把",
#         "id": "10158570278459750_10160060609644750"
#       },
#       {
#         "created_time": "2021-07-29T03:43:25+0000",
#         "message": "I acknowledge your acknowledgements.\n\n#眾人皆醉沒有人醒 #英文好難",
#         "id": "10158570278459750_10160052800489750"
#       },
#       {
#         "created_time": "2021-07-08T06:22:39+0000",
#         "message": "有沒有7/12之後是2+2.2361i級的八卦? 就是號稱標準(norm)是3級, 但實質部分只有2級?\n\na=2+2.2361i; norm(a) = 3.0000\n\n#複變學得好一輩子沒煩惱",
#         "id": "10158570278459750_10160007084659750"
#       },
#       {
#         "created_time": "2021-03-23T03:47:13+0000",
#         "message": "米國真是太危險惹~\n\nhttps://en.wikipedia.org/wiki/List_of_mass_shootings_in_the_United_States_in_2019\n\nhttps://en.wikipedia.org/wiki/List_of_mass_shootings_in_the_United_States_in_2020\n\nhttps://en.wikipedia.org/wiki/List_of_mass_shootings_in_the_United_States_in_2021",
#         "id": "10158570278459750_10159745511144750"
#       },
#       {
#         "created_time": "2021-03-11T13:15:22+0000",
#         "message": "救救台大AI中心 XD",
#         "id": "10158570278459750_10159713128904750"
#       },
#       {
#         "created_time": "2021-01-15T09:38:47+0000",
#         "message": "程式真的做不出來該怎麼辦？\n\n#文章其實是寫給PM看的 #研究也適用 #以下開放各種抱怨",
#         "id": "10158570278459750_10159546007274750"
#       },
#       {
#         "created_time": "2021-01-11T09:14:10+0000",
#         "message": "剛畢業因故沒辦法留學，或是年後想換工作嗎？  \n\n誠徵【網站前/後端全職/兼職工程師】  \n\n工作主題: 建置「臺灣社會科學腦造影暨行為研究資料庫」網站  \n\n工作時期: 2021年2月~2022年7月至少18個月  \n\n工作地點: 台大心理學系 / 台大永齡生醫工程館 / 在家  \n\n工作薪資: 台大研究助理標準薪資(https://ppt.cc/fGQjHx) + 15%彈性加給; 享勞健保與其他校內人員福利  \n\n工作資格: [前端] React (+Hooks), CSS, & RWD; [後端] Flask, MySQL, & MongoDB (因需整合舊程式，熟悉PHP者為佳)\n\n工作內容: 與技術專案經理(熟悉前後端與伺服器)及前/後端人員共三人團隊，在科技部前瞻司/人文司與台大/政大/成大三校腦造影中心的指導下，於國家高速網路與計算中心的雲端上建置一全國性之資料庫查詢/共享網站。網站已有部分規格/程式碼，但仍有其它全新機制/內容待討論/開發。\n\n本工作適合對基礎網站開發已有經驗、想要挑戰開發進階/大型網站、有意建立代表作/作品集、或是對神經資訊學(Neuroinformatics)有興趣的夥伴。歡迎對神經科學、行為科學、AI/機器人的整合有興趣者加入「模型建構與資訊學實驗室」的大家庭!\n\n意者請email聯絡黃從仁老師(trhuang@ntu.edu.tw)，並附上個人中文或英文簡歷(CV)與自我推薦信(Cover Letter)。謝謝！",
#         "id": "10158570278459750_10159536084364750"
#       },
#       {
#         "created_time": "2020-12-30T07:37:44+0000",
#         "message": "大家狂熬夜趕出來的遊戲今天終於要上線公測了!\n\n我想 ，這種極度痛苦後，看到成品的滿足感，大概就是正向心理學中所謂的真正幸福(eudaimonia)吧!?\n\n#感謝團隊",
#         "id": "10158570278459750_10159495408909750"
#       },
#       {
#         "created_time": "2020-10-27T02:25:28+0000",
#         "message": "我小時候以為大學是一個在風和日麗時可以坐在樹下悠閒看書、享受知識的地方...\n\n結果我昨天忙到凌晨三點才睡，而上級和下屬也分別在三點多和四點多因工作來信...\n\n期待周末農閒時能狂補眠，周間只能多來點特大悲咖啡星冰樂壓壓驚...",
#         "id": "10158570278459750_10159324250554750"
#       },
#       {
#         "created_time": "2020-10-15T03:18:30+0000",
#         "message": "十月底遭各種討業績集團連番攻擊\n\n#雖然憨慢還是要快逃",
#         "id": "10158570278459750_10159291167624750"
#       },
#       {
#         "created_time": "2020-10-08T01:36:06+0000",
#         "message": "好書推薦：Mindf*ck 心智操控【劍橋分析技術大公開】\n\n根據2020年初的統計資料，臺灣有近八成五的上網人口，而這其中約有九成是臉書（ Facebook ）的使用者。我們打開臉書，除了好奇地瀏覽舊識與新交的近況，也不忘抒發心情並記錄下自己的生活點滴與這些朋友們分享。較不在乎個人隱私的使用者，除了在個人的介紹頁面中如實地填入如性別、年紀、居住地等基本資料外，也無所顧忌地留下如宗教信仰、政治立場、與戀愛性向等進階資訊。相反地，較在意維護個人隱私的使用者，時常在臉書的使用上遵循著四不一沒有的原則：非必要不填個人資料、不主動張貼留言、不分享影音照片、不與他人有過多互動，於是逐漸沒有朋友……\n\n「我po這些東西本來就是要給朋友看的啊！」，您義正詞嚴。問題是：有些內容您的朋友不想看（例如一早刷牙流血的照片），且能看到的不一定是您的朋友（例如您在臉書資料科學團隊工作的情敵）。本書的作者克里斯多福·懷利 (Christopher Wylie) ，具有「劍橋分析」（Cambridge Analytica）公司的多個頭銜──共同創辦人、前研究總監、以及吹哨者。懷利在本書中用自傳式的口吻，娓娓道來他們的團隊如何利用早期臉書敞開的資安大門，大量地去搜刮臉書上數億個使用者的資訊，並進一步地將這些臉書與其他資料來源做串接。當他們恣意地去檢視素昧平生的臉書使用者房子的衛星照片、家人照片、以及各種癖好時，您與我可能都是他們所輕蔑嘲笑的那個怪胎。\n\n「那又怎麼樣？」，您一臉不屑。《東周列國志》中，文種曾對越王勾踐獻策：「今王志在報吳，必先投其所好，然後得制其命」。歷史的教訓是 ：個人的特質、價值、偏好、或心中最深層的恐懼一旦被精準掌握，輕則個人被利用，重則導致國破家亡。懷利在本書中列舉了許多這種掌控人心，操弄各國選舉的範例。不若過去的政治宣傳活動般只依照性別、年紀、居住地等人口學資料來將選民分類，他們透過臉書上的動態消息、追蹤、按讚、分享等數位足跡（digital footprints）來對臉書的使用者做心理剖繪（psychological profiling），讓政治宣傳能夠見人說人話，見鬼說鬼話，人鬼盡歡。\n\n「就像是谷歌（Google）與亞馬遜（Amazon）所做的個人化廣告推薦那樣嗎？」，您好奇。不，沒那麼簡單！他們會在臉書鎖定欲操弄的對象（如其客戶欲殲滅的對手陣營或文化團體）來創建粉絲專頁，在吸引心理特質與政治/文化理念相似的使用者後，首先於粉專中測試怎樣的話術或假消息最能夠煽動這個同溫層， 之後再把有效的謠言透過暗樁在線上或線下的相關團體中做大規模的傳播，達到心戰目的。這裡的對手陣營可以像是政治組織或公司行號，文化團體可以像是女性主義或是特定宗教等各種社團。\n\n作者聲稱2013年才建立的「劍橋分析」公司便是透過如此的精準投放（microtargeting）來影響2016年的英國脫歐公投以及當年的美國總統大選結果等世界重大歷史事件。和實驗室的心理學實驗不同，這些真實生活中的心智操控，除了\"受控者\"並非在知情同意（informed consent）的情況下被操弄，也無徹底不受到假新聞污染的\"控制組\"可供比較。因此，雖然書中所提的選舉結果對「劍橋分析」來說可謂是稱心如意，但科學上不能推斷這些操弄是否真有效果或是有多少效果。換句話說，這些書中所提的選舉結果，有可能真是「劍橋分析」的豐功偉業，也有可能僅是歷史上的因緣巧合。不過即便是後者，本書所介紹的各種心理剖繪與心智操控技術，的確也都有其學術研究的基礎，而「劍橋分析」所濫用這些技術的方式，也令人大開眼界並有所省思。\n\n水能載舟，亦能覆舟。 整個懷利人生上半場的故事中，最諷刺的莫過於他本來懷抱著理想，想用科技和創新來改善政治和世界，最後卻淪為別人的政治工具在世界各處鼓動仇恨和對立；而懷利原本在他一手打造的「劍橋分析」公司中透過大數據監控他人，卻在他踢爆公司內情後反過頭來受到各方奪命式的監控；到最後，這個科技頑童不得不盡量遠離網路、電腦、與手機，反璞歸真地過著低科技的生活。由此可見，科技本身是中性的，其影響是好是壞端看是落在好人或壞人手中。當我們一方面享受著網路與社群媒體所帶來的便利，大方地送出個資來換取個人化服務的同時，我們也應當意識到：在世界的某個暗黑一隅，一台電腦之前，可能有個像上帝的老大哥時時刻刻地在瞪大雙眼看顧著我們，而且更重要的是：一切都在他的掌控之中……\n\n「我彷彿看到了這位老大哥」，您若有所感。\n\n等等！您不會正是作者口中那個疑神疑鬼而容易相信陰謀論的高神經質者吧！？",
#         "id": "10158570278459750_10159270622199750"
#       },
#       {
#         "created_time": "2020-09-23T02:32:24+0000",
#         "message": "有時會和一群chatbots聊到哭笑不得",
#         "id": "10158570278459750_10159226938739750"
#       },
#       {
#         "created_time": "2020-09-06T14:22:00+0000",
#         "message": "海水退潮了就知道我有穿褲子!\n\n被懷疑做不出來的計畫我還是完成了喔~\n\n#GetThingsDone #MakeThingsHappen",
#         "id": "10158570278459750_10159181037414750"
#       },
#       {
#         "created_time": "2020-07-29T16:14:29+0000",
#         "message": "【手把手的教與學】\n\n看了學生的程式，大致是對的，但在小細節上出了一些錯誤，導致最後的研究結論仍是錯的。不過此時所浮現的倒是正面而不是負面的情緒～\n\n該怎麼說呢？學生的情況像是拉筋或做瑜珈，初學者模仿老師的外型動作，但因為沒有透徹了解一個姿勢的內涵和目的，姿勢常常沒有掌握要領拉到內在該拉的東西。不過這也不是學生的錯，而是一個學習技藝、掌握技藝的自然過程，需要老師手把手地耐心修正。\n\n「養兒方知父母恩」，當了老師才知道原來要把學生一路捏捏捏，捏到成熟其實頗費心力。於是我開始感念起不嫌棄我資質駑鈍，仍願意幫我調整各種觀念/動作的老師們......\n\n我相信有一天我一定能不負老師們的指導，代表傳武界打敗徐曉冬! (喂! 跑錯棚?)\n\n#師徒制的浪漫",
#         "id": "10158570278459750_10159069660009750"
#       },
#       {
#         "created_time": "2020-07-16T05:29:13+0000",
#         "message": "萬事問臉友:\n\n有一隻鳥跟著我們的車回家了。牠可能是受傷了，現在停在電箱上面休息。牠這樣不吃不喝下去也不是辦法，請問該怎麼處理?",
#         "id": "10158570278459750_10159028550044750"
#       },
#       {
#         "created_time": "2020-06-30T05:27:28+0000",
#         "message": "萬事問臉書2: 為何這個KNN比SVR更神?\n-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-\nimport numpy as np\nfrom sklearn import model_selection,neighbors\nfrom scipy.stats import pearsonr\nX=np.zeros((200,1))\nY=np.random.rand(200)\nYp=model_selection.cross_val_predict(neighbors.KNeighborsRegressor(199),X,Y,cv=200) # leave-1-out \nprint('correlation:',pearsonr(Y,Yp))\n-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-\ncorrelation: (-1.0, 0.0)",
#         "id": "10158570278459750_10158974763514750"
#       },
#       {
#         "created_time": "2020-06-30T05:13:16+0000",
#         "message": "萬事問臉書: 為何這個SVR這麼神?\n-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-\nimport numpy as np\nfrom sklearn import model_selection,svm\nfrom scipy.stats import pearsonr\nX=np.zeros((200,1)) # 200 samples of zeros \nY=np.random.rand(200) # random continuous Y\nYp=model_selection.cross_val_predict(svm.SVR(),X,Y,cv=200) # leave-1-out \nprint('correlation:',pearsonr(Y,Yp)) \n-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-\ncorrelation: (-0.9276546220323998, 1.2158583522119985e-86)",
#         "id": "10158570278459750_10158974739739750"
#       },
#       {
#         "created_time": "2020-06-28T10:11:48+0000",
#         "message": "關於某科科部各種計畫審查，我想說的是……. \n\n如果我們能不吝給學生鼓勵，為何不能給同行溫暖而總要受囿於角色內行為砍個彼此血流如注?\n\n#冤冤相報何時了處處蚊子咬 #把愛傳出去TrenCanHelp #科科",
#         "id": "10158570278459750_10158968799149750"
#       },
#       {
#         "created_time": "2020-06-28T09:52:45+0000",
#         "message": "TCPSR八月起會在台北進行八次實體活動，因此想徵求一位台大學生擔任助理，協助社群活動與媒體經營。因為其任務以經營網路社群為主，不需要每場都要到現場，主要工作是事前發佈活動資訊 與事後在各大社群平台整理傳播活動紀錄，行政事項主要是核銷外縣市參與老師的交通費及活動餐費。如果對參與TCPSR研讀班課題有興趣的學生，請直接聯絡陳紹慶老師(pmsp96@gmail.com)。\n\n#工商服務",
#         "id": "10158570278459750_10158968759414750"
#       },
#       {
#         "created_time": "2020-05-20T09:31:13+0000",
#         "message": "只是喜歡讀書就一直讀下去，但研究與教學太忙反而沒時間讀閒書。\n\n只是喜歡玩電腦就一直玩下去，但相關的服務工作中都狂被電腦玩。\n\n只是想多點相處的時間就結婚， 但光應付兩寶的教養就已心力交瘁。\n\n所以說婚不能亂結、電腦不能亂玩、書不能亂讀～（飄走）",
#         "id": "10158570278459750_10158825677209750"
#       },
#       {
#         "created_time": "2020-04-26T08:50:54+0000",
#         "message": "和不能睡過夜嬰兒一起生活的結果就是紅茶、抹茶、咖啡、B群輪著喝。\n\n現在此嬰睡很深讓本魯可以偷閒在這裡發廢文，想必晚上兩人又要一起失眠惹~\n\n#蠻牛CanHelp #此嬰IsHelping",
#         "id": "10158570278459750_10158728226349750"
#       },
#       {
#         "created_time": "2020-04-20T15:03:14+0000",
#         "message": "【代徵才】資策會資訊處\n\n1. 職務：程式設計/分析師\n2. 內容：負責整合全會各資訊系統，工作內容包含程式開發與使用者需求發展\n3. 要求技能1(後端)：熟悉C#、net core / MVC\n4. 要求技能2(前端)：jQuery、Angular(二擇一)\n5. 要求技能3(資料庫)：MS-SQL\n6. 其他要求：多益750分以上；略懂資訊系統發展與管理，例如PMP、CMMI…等\n7. PLUS：熟Java、Python\n\n連絡人：資訊處技術服務組組長，莊文德。Mail： peterchuang@iii.org.tw , TEL: 02-6631-8116\n\n#救救資策會 #YouCanHelp",
#         "id": "10158570278459750_10158701300799750"
#       },
#       {
#         "created_time": "2020-03-09T09:53:30+0000",
#         "message": "「確認過眼神」是哪一招？",
#         "id": "10158570278459750_10158532087604750"
#       }
#     ],
#     "paging": {
#       "previous": "https://graph.facebook.com/v4.0/10158570278459750/posts?access_token=EAAYAOVZA9YWQBADX7gnvTQoQ5e5SxMmTqwVtMP4EcM4AvK4hcd5zduK20gtfqJEzVWlvkMIJQ8wwBC8ZB10wMbmV68vbpbRoR4dRiFVsEpVGKpwzutXT1RoYSOAyTmgJ6pb7d86ZBwWeevTk6WmHzLKlvR2v8wV6S0Pj2oeuLmOZBYkqNYLVwoTJoF1XRhuQ2GLCIsIBZBQZDZD&__previous=1&since=1634195416&until&__paging_token=enc_AdCfHvQB7AAoZACSmm1ulThL2ZBn5wblwHFRTpSGrsSFYcVIYaAbngfkXAkjZBEXQvyBZAh969O7xjjFaGTReSdRnkqZAgKJiFulq27UkReZBVIRjf1P5F1VlfIC7WXXfSSchQTU8ZD",
#       "next": "https://graph.facebook.com/v4.0/10158570278459750/posts?access_token=EAAYAOVZA9YWQBADX7gnvTQoQ5e5SxMmTqwVtMP4EcM4AvK4hcd5zduK20gtfqJEzVWlvkMIJQ8wwBC8ZB10wMbmV68vbpbRoR4dRiFVsEpVGKpwzutXT1RoYSOAyTmgJ6pb7d86ZBwWeevTk6WmHzLKlvR2v8wV6S0Pj2oeuLmOZBYkqNYLVwoTJoF1XRhuQ2GLCIsIBZBQZDZD&until=1583747610&since&__paging_token=enc_AdDb7hSUn2rbhjRrlEvBTezvqEVOevZCktfMXjFuCHSSXMiSZA4RPNxMH8V96RWWEDdK8uBTCr2w8cXlctdDgra181M4cCprKAOXBaSDHt6ZAQ8sl82CMCy6frL7vr2qWD9qVEZD&__previous"
#     }
#   }
# }

# %% [markdown]
# ## Twitter

# %%
import tweepy
key1='HDTBqZDAOuZJyDhsr5Z5tw' # API key 
secret1='nKULl80bwwedY4jtk4UTt2dXotoIVOlPQ8fUVK2LDo' # API secret
key2='206228745-rPUeOG5ZP6Wi3nV5Zd4bwYLRkxthdHVMuidsAbRn' # Access token  
secret2='XcPdcCDXu54FpaYD58KrBQTkCJwsQOdiFpQCbOLh2D09N' # Token secret
auth=tweepy.OAuthHandler(key1,secret1)
auth.set_access_token(key2,secret2)
api=tweepy.API(auth)
data=api.search_tweets(q=u'高雄',geocode='22.78,120.555,500km')
for tweet in data:
  print(tweet.user.screen_name,tweet.text,'\n')
# Out:
# PeterChuang0730 身為一個身份證字號E開頭，在高雄居住時間是在台北居住時間的2倍以上的、名義上的天龍國國民，別的縣市我不知道，但我敢說，檳榔集團在高雄，已經騙不到綠營的票
#
# 2ggame I'm at 嵐山-高雄パークウェイ 観空台 in Kyoto, Kyōto https://t.co/IulGC5kknv
#
# PeterChuang0730 明年可以自己選或派林鄭選高雄市長，看會不會突破4趴 https://t.co/XKWHm7u8l8
#
# MDFK7777 @asdfg00774379 哈囉，寶😍
# 我也高雄～ 希望可以聊聊😊 https://t.co/UuSaj0Rt3V
#
# arvin14256076 @PUR83usmOUumGUp @love11041230 你好阿
# 問題是我們在高雄市區
# 很遠喔
#
# hao520 公園陸橋南側、高雄港方向的景。週末輕軌班距密一點。如果是平日下午，雙向各等一到兩班車來真的會曬死。 @ 哈瑪星天空雲台 https://t.co/G36r0p3WFw
#
# hao520 高雄輕軌電車通過北號誌樓。期待北號誌樓早日修復完成。 @ 北號誌樓 https://t.co/oBcgbtZPdT
#
# MathewLong19 @iingwen 美国阿猫阿狗死了@iingwen都要问候两句，高雄火灾都过了这么久了，你视而不见，听而不闻？
#
# hinhung0119 高雄大火｜蔡英文探火災傷者　陳其邁：或拆除涉事大樓
# https://t.co/yDEUG5BdCv
#
# hinhung0119 高雄大火｜兩女死者身分未明　招魂法會家屬喊判疑犯死刑
# https://t.co/t9NVqf42ke
#
# lulu3866 城中城大樓火警死傷慘重，蔡英文總統事發第3天南下，16日到高雄各醫院探視傷者，但在殯儀館弔唁死者僅5分鐘就快閃。
#
# lulu3866 「高雄大火，結果晚上政論節目都在檢討台北。」
#
# lulu3866 城中城大火釀嚴重死傷，高雄市長陳其邁是否應依照當年要求胡志強下台的標準主動請辭市長，民進黨立委劉世芳表示，「韓國瑜也當過2年市長」。對此，國民黨主席朱立倫痛斥，這是最無恥的講法，若要這樣往前推，是不是還要推到陳菊也擔任10幾年市長？台北市長柯文哲則說，
#
# taiwanrider2001 おはようございます！
# 台湾高雄、天候晴れ☀只今気温26℃
# 昨日、観光名所の太魯閣で落石がありバイクに激突、転倒骨折というニュースがありました。先週3日で1,000mmを超える大雨。大雨のあとは絶対に走っちやいけない道と改めて認識し… https://t.co/fVcl8t11Kz
#
# lulu3866 說來悲哀，台灣社會的進步，幾乎是由一件件悲劇堆疊出來的。因彭婉如及白曉燕命案有了《性侵害犯罪防治法》，鄧如雯殺夫案催生《家庭暴力防治法》；近日高雄城中城惡夜大火，也喚醒立委呼籲翻修《消防法》、《公寓大廈管理條例》等。但更可悲的是，連悲劇也撼動不了的政治醬缸，

# %%
for follower in api.get_follower_ids(screen_name='iingwen'):
  user=api.get_user(user_id=follower)
  print(user.screen_name,'\t',user.name)
# Out:
# xuejianlun2021 	 xuejianlun2021
# jiwiaaa 	 jiwi
# yoshi120226 	 大和民族
# tedchen545 	 tedchen545@gmail.com
# 8_foyca 	 菲菲
# jTP7R7Up3reWVpf 	 郁姝
# asalassi27 	 A. Salassi
# wysun85 	 Tony Sun
# kurolisu 	 にゃーん
# 6T9bX43jAI4dTkY 	 垚垚曦
# BeijingSasha 	 Саша-Пекин
# isaono88hitomi 	 ひとみ子
# ze_cheng_yu 	 ze cheng yu
# qddsdq 	 Tzu-Miao Chen
# jojojodajo78 	 じょうじー
# harashiroyago 	 akayago
# young_sik_quy 	 上海之根 文明松江
# kemingci1 	 柯銘賜
# Harkin666 	 Harkin
# wowojieq 	 愚蠢的人类
# SrtUIL3Z0dqDhOv 	 黃品頣
# lP6R30mxjbdJLy9 	 鄧皓文
# touchdown_China 	 touchdownman
# tHv0J4shxECKGTE 	 にし
# kelisido 	 Li Ke
# tyxhs900321 	 二小队铁二小
# AndyZenki 	 Andy Lin
# AungTheinSai1 	 SMILE
# lbp8LsR4jI2jQMp 	 松本勝男
# xSivc9yKjYh5tvw 	 金洋勇
# jcadtWbYTSH9YCy 	 園田誠
# xingyueleng777 	 星月冷
# ZD98956822 	 ZD
# y4419m 	 y4419m
# weijin52802094 	 韦锦
# Ddyar2s 	 日拱一豬
# sasazawa5 	 @_sasazawa
# 3iliXJYZbEpbiWG 	 KK
# dJ2eRLO5uT1ghNS 	 蒲公英
# T05952099 	 T罗伯特
# WillWil37320418 	 WillWill
# toothfully 	 Chan Joon Yee
# Linxxx1988 	 L
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-c93d50d23f85> in <module>
#       1 for follower in api.get_follower_ids(screen_name='iingwen'):
# ----> 2   user=api.get_user(user_id=follower)
#       3   print(user.screen_name,'\t',user.name)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tweepy/api.py in wrapper(*args, **kwargs)
#      44             kwargs['payload_list'] = payload_list
#      45             kwargs['payload_type'] = payload_type
# ---> 46             return method(*args, **kwargs)
#      47         wrapper.payload_list = payload_list
#      48         wrapper.payload_type = payload_type
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tweepy/api.py in get_user(self, **kwargs)
#    2421         https://developer.twitter.com/en/docs/twitter-api/v1/accounts-and-users/follow-search-get-users/api-reference/get-users-show
#    2422         """
# -> 2423         return self.request(
#    2424             'GET', 'users/show', endpoint_parameters=(
#    2425                 'user_id', 'screen_name', 'include_entities'
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tweepy/api.py in request(self, method, endpoint, endpoint_parameters, params, headers, json_payload, parser, payload_list, payload_type, post_data, files, require_auth, return_cursors, upload_api, use_cache, **kwargs)
#     214                 # Execute request
#     215                 try:
# --> 216                     resp = self.session.request(
#     217                         method, url, params=params, headers=headers,
#     218                         data=post_data, files=files, json=json_payload,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~/opt/anaconda3/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Google

# %%
DEVELOPER_KEY = "AIzaSyAUzMOVN4RV3Opf0Z9wIMGLADcXtpVUPpk"

# %%
from googleapiclient.discovery import build
youtube = build('youtube', 'v3', developerKey=DEVELOPER_KEY)
result = youtube.videos().list(
    part='snippet,contentDetails,statistics',
    chart='mostPopular',
    regionCode='TW',maxResults=50).execute()
print(result)
# Out:
# {'kind': 'youtube#videoListResponse', 'etag': 'wy9yF-Wem4I604ji8z4m7E8araw', 'items': [{'kind': 'youtube#video', 'etag': 'n7HRGvkXlvzoCdjv1jGnW6jFkzg', 'id': '-Rp7UPbhErE', 'snippet': {'publishedAt': '2021-10-15T10:00:12Z', 'channelId': 'UCFUtqTcgJgRnmZ3tMU6P74Q', 'title': '聽見玻璃心碎的聲音... 黃明志 Ft.陳芳語【玻璃心】@鬼才做音樂 2021 Ghosician', 'description': "這是一首充滿了粉紅色的浪漫甜蜜情歌，請玻璃心患者慎入... 也請大家關注黃明志最新剛剛開的微博賬號 https://weibo.com/u/7684024922\n\n@Kimberley Chen  is in the house! Opps! We didn't mean to break your heart...💔\n\n⚠️Please be cautious if you are Fragile Pink⚠️\n\n黃明志2021最新實體專輯【鬼才做音樂】11月正式發行，今天開始預購！Namewee's latest music album of 2021 [Ghosician] will be officially released in November, and Pre-order starts today! https://bit.ly/3BM4IIe\n\n\n《玻璃心 Fragile》Youtube 高清版MV：https://bit.ly/30GjD9j\n\nThe Making Of《玻璃心 Fragile》幕後花絮 Youtube高清版 : https://youtu.be/TTd7M9QjM3M\n\n《玻璃心 Fragile》數位音樂下載 Online Music Download：https://lnk.to/fragilepink\n\n《玻璃心 Fragile》Shorts 高清版：https://youtu.be/PdoGtBQFtbg\n\n《玻璃心 Fragile》幕後花絮 Shorts 高清版：https://youtu.be/lFghyBIjsO0\n\nKimberley Chen 陳芳語 Official Facebook Fan Page:\nhttps://www.facebook.com/heyitskimberley\n\nKimberley Chen 陳芳語 :\ninstagram.com/lekimberleyy\n\n-\n\n欲網購黃明志最新實體專輯《亞洲通才》及歷年專輯和周邊商品請到。Purchase Namewee Latest 《Asian Polymath》 , Others Music Albums & Merchandises Please log in to https://namewee4896.com/\n\nNamewee 黃明志 Telegram Channel :\nhttps://t.me/nameweeofficial\n\nNamewee 黃明志 Official Facebook Fan Page:\nhttps://www.facebook.com/namewee/\n\nNamewee YouTube Channel Link:\nhttp://www.youtube.com/namewee/\n\nNamewee Twitter Channel Instagram:\n@NameweeO\n\n#Namewee #黃明志 #陳芳語 #KimberleyChen #玻璃心 #Fragile", 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/-Rp7UPbhErE/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/-Rp7UPbhErE/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/-Rp7UPbhErE/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/-Rp7UPbhErE/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/-Rp7UPbhErE/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'channelTitle': 'Namewee', 'tags': ['玻璃心', 'fragile', '小粉紅', 'Kimberley Chen', '陳芳語', 'Kimberley', 'kimberleychen', 'heyitskimberley', 'namewee', '黃明志', 'pink', '鬼才做音樂', 'Ghosician', '粉紅', '可愛', 'rnb', 'Rhythm and blues', "R'n'B", '陈芳语', '4AM Calls', '愛你', 'AINI', 'good times', '分手說愛你', 'cute', 'lekimberley', '攝徒', '蒟蒻講乾話', '視網膜', '館長', '博恩', '波特王', 'Joeman', '杜汶澤', 'triggered', 'panda', 'bat', '熊貓', '蝙蝠'], 'categoryId': '10', 'liveBroadcastContent': 'none', 'defaultLanguage': 'zh-TW', 'localized': {'title': '聽見玻璃心碎的聲音... 黃明志 Ft.陳芳語【玻璃心】@鬼才做音樂 2021 Ghosician', 'description': "這是一首充滿了粉紅色的浪漫甜蜜情歌，請玻璃心患者慎入... 也請大家關注黃明志最新剛剛開的微博賬號 https://weibo.com/u/7684024922\n\n@Kimberley Chen  is in the house! Opps! We didn't mean to break your heart...💔\n\n⚠️Please be cautious if you are Fragile Pink⚠️\n\n黃明志2021最新實體專輯【鬼才做音樂】11月正式發行，今天開始預購！Namewee's latest music album of 2021 [Ghosician] will be officially released in November, and Pre-order starts today! https://bit.ly/3BM4IIe\n\n\n《玻璃心 Fragile》Youtube 高清版MV：https://bit.ly/30GjD9j\n\nThe Making Of《玻璃心 Fragile》幕後花絮 Youtube高清版 : https://youtu.be/TTd7M9QjM3M\n\n《玻璃心 Fragile》數位音樂下載 Online Music Download：https://lnk.to/fragilepink\n\n《玻璃心 Fragile》Shorts 高清版：https://youtu.be/PdoGtBQFtbg\n\n《玻璃心 Fragile》幕後花絮 Shorts 高清版：https://youtu.be/lFghyBIjsO0\n\nKimberley Chen 陳芳語 Official Facebook Fan Page:\nhttps://www.facebook.com/heyitskimberley\n\nKimberley Chen 陳芳語 :\ninstagram.com/lekimberleyy\n\n-\n\n欲網購黃明志最新實體專輯《亞洲通才》及歷年專輯和周邊商品請到。Purchase Namewee Latest 《Asian Polymath》 , Others Music Albums & Merchandises Please log in to https://namewee4896.com/\n\nNamewee 黃明志 Telegram Channel :\nhttps://t.me/nameweeofficial\n\nNamewee 黃明志 Official Facebook Fan Page:\nhttps://www.facebook.com/namewee/\n\nNamewee YouTube Channel Link:\nhttp://www.youtube.com/namewee/\n\nName ...

# %%
def youtube_search(q, max_results=50,order="relevance", token=None, location=None, location_radius=None):

    youtube = build('youtube','v3',developerKey=DEVELOPER_KEY)

    search_response = youtube.search().list(
    q=q,
    type="video",
    pageToken=token,
    order = order,
    part="id,snippet", # Part signifies the different types of data you want 
    maxResults=max_results,
    location=location,
    locationRadius=location_radius).execute()

    title = []
    channelId = []
    channelTitle = []
    categoryId = []
    videoId = []
    viewCount = []
    likeCount = []
    dislikeCount = []
    commentCount = []
    favoriteCount = []
    category = []
    tags = []
    videos = []
    
    for search_result in search_response.get("items", []):
        if search_result["id"]["kind"] == "youtube#video":

            title.append(search_result['snippet']['title']) 

            videoId.append(search_result['id']['videoId'])

            response = youtube.videos().list(
                part='statistics, snippet',
                id=search_result['id']['videoId']).execute()

            channelId.append(response['items'][0]['snippet']['channelId'])
            channelTitle.append(response['items'][0]['snippet']['channelTitle'])
            categoryId.append(response['items'][0]['snippet']['categoryId'])
            favoriteCount.append(response['items'][0]['statistics']['favoriteCount'])
            viewCount.append(response['items'][0]['statistics']['viewCount'])
            likeCount.append(response['items'][0]['statistics']['likeCount'])
            dislikeCount.append(response['items'][0]['statistics']['dislikeCount'])
 
        if 'commentCount' in response['items'][0]['statistics'].keys():
            commentCount.append(response['items'][0]['statistics']['commentCount'])
        else:
            commentCount.append([])
        if 'tags' in response['items'][0]['snippet'].keys():
            tags.append(response['items'][0]['snippet']['tags'])
        else:
            tags.append([])

    youtube_dict = {'tags':tags,'channelId': channelId,'channelTitle': channelTitle,'categoryId':categoryId,'title':title,'videoId':videoId,'viewCount':viewCount,'likeCount':likeCount,'dislikeCount':dislikeCount,'commentCount':commentCount,'favoriteCount':favoriteCount}

    return youtube_dict

# %%
import pandas as pd
test = youtube_search("高雄")
df = pd.DataFrame(data=test)
df
# Out:
#                                                  tags  \
# 0                      [台灣美食, 台灣, 高雄美食, 高雄, 傳統小吃, 火鍋]
# 1                            [高雄, 鹽埕區, 駁二, 鴨肉珍, 樺達奶茶]
# 2   [ETTV, Ch51, 東森, EBC, 白心儀, 1001, 1001個故事, 東森新聞...
# 3   [高雄, 高雄景點, 高雄旅遊, 高雄行程, 2021新景點, 大港橋, HOLOPARK,...
# 4                                                  []
# 5   [小吃, 餐廳, 料理, Peter, su, 李易, 韋汝, 心緹, 阿達, 小鐘, 吳鳳...
# 6   [ettoday, 東森, 新聞, ETtoday, 新聞雲, 雲端, 投資, 理財, 雲端...
# 7   [国民大会, 國民大會2020大白話, 于美人, 陳鳳馨, 黃暐瀚, 錢怡君, 习近平, 中...
# 8   [壹加壹, 一加一, ILLY and LEAN, ILLY, LEAN, 高雄, 景點, ...
# 9                                                  []
# 10  [我是馬鈴薯小姐雁靈, 高雄旅遊, 台灣旅遊, 兩天一夜遊, 吃貨行程, 高雄必吃美食, 丹...
# 11                                 [高雄美食, 高雄小吃, 高雄必吃]
# 12                [華視, 新聞, 朱培滋, 高雄, 陳柏惟, 罷免, 支持, 國民黨]
# 13  [新聞雲, ettoday, 東森, 新聞, 政治, 大南方崛起, 陳其邁, 高雄發展, 高...
# 14  [進擊的台灣, 東森財經, 美食, 小吃, 進擊, 進擊台灣, 进击的台湾, 進擊的臺灣, ...
# 15  [進擊的台灣, 東森財經, 美食, 小吃, 進擊, 進擊台灣, 进击的台湾, 進擊的臺灣, ...
# 16  [進擊的台灣, 東森財經, 美食, 小吃, 進擊, 進擊台灣, 进击的台湾, 進擊的臺灣, ...
# 17  [非凡新聞, 非凡財經新聞, 台積電, 晶圓代工, 7奈米, 高雄, 陳其邁, 當沖, 聯電...
# 18  [udn video, udn tv, 聯合報, 聯合新聞, 社群熱搜, 最新直播, 蔡英文...
# 19                         [華視, 新聞, 莊雨潔, 五倍券, 夜市, 加碼]
# 20                          [華視, 新聞, 葉映彤, 大火, 火警, 政府]
# 21                                                 []
# 22                                     [非凡新聞, 非凡財經新聞]
# 23                      [華視, 新聞, 連珮貝, 大樓, 失火, 受困, 死亡]
# 24  [台湾, 台湾新闻, 中時電子報, 新聞, ctv, chinatv, 中視新聞, chin...
# 25  [新聞雲, ettoday, 東森, 新聞, 社會新聞, 火災, 城中城, 高雄, 城中城 ...
# 26  [少康戰情室, 少康, 習近平, 习近平, XiJinping, 大陸, 中國, 中国, 少...
# 27  [TBS, NEWS, ニュース, TBSNEWS, 報道, 日本, Japan, 最新ニュース]
# 28  [台中市, 城中城大樓, 後製中心, 採訪中心, 火警, 王金平, 胡志強, 陳其邁, 馬英...
# 29                          [華視, 新聞, 莊雨潔, 女嬰, 虐待, 死亡]
# 30                                                 []
# 31  [非凡新聞, 非凡財經新聞, 20210927A113, 五輕, 半導體, 2330, 台積...
# 32                                      [華視, 新聞, 朱培滋]
# 33                                      [nownews, 新聞]
# 34  [東森, 東森新聞, EBC, 新聞, news, Ch51, 台灣, ㄉㄨㄥ森新聞, 東森...
# 35  [国民大会, 國民大會2020大白話, 于美人, 陳鳳馨, 黃暐瀚, 錢怡君, 习近平, 中...
# 36  [三立新聞網, 三立, SETN, 新聞, 即時新聞, 新聞影音, 新聞影片, 看新聞, 看...
# 37  [新聞雲, ettoday, 東森, 新聞, 社會新聞, 火災, 城中城, 高雄, 城中城 ...
# 38                                                 []
# 39  [TVBS, TVBS新聞, LIVE, 新聞直播, 直播, 現場, 國際, 娛樂, 政治,...
# 40  [ettoday, 東森, 新聞, ETtoday, 政治, 新聞直播, LIVE, liv...
# 41  [台湾, 台湾新闻, 中時電子報, 新聞, ctv, chinatv, 中視新聞, chin...
# 42  [三立新聞網, 三立, SETN, 新聞, 即時新聞, 新聞影音, 新聞影片, 看新聞, 看...
# 43                          [華視, 新聞, 朱培滋, 大樓, 火災, 救援]
# 44  [ETTV, Ch51, 東森, EBC, 白心儀, 1001, 1001個故事, 東森新聞...
# 45  [非凡大探索, 美食大探索, 劉祝華, 野饌燒肉火烤兩吃活泰國蝦吃到飽, 高雄市鳳山區美食,...
# 46  [ettoday, 東森, 新聞, ETtoday, 新聞雲, 雲端, 投資, 理財, 雲端...
# 47             [中天, 中天電視, 中天新聞, CTI, 會員, 火警, 城中城, 爆炸]
# 48  [TTVNews, 生活新聞, 國慶, 煙火, 國慶日, 高雄港, 周邊, 人潮, 今年, ...
# 49  [寰宇新聞台, 寰宇國際新聞, 寰宇新聞, 寰宇news, globalnewstv, 寰宇...
#
#                    channelId            channelTitle categoryId  \
# 0   UC5H-l11nc7q5XqMRtaU-oYA                     陪沈團         22
# 1   UC9i2Qgd5lizhVgJrdnxunKw                   千千進食中         22
# 2   UCPlO3Az7v08IUdl9RuKRUVA               台灣1001個故事         25
# 3   UCOQZJC11Gjca5PGeM4-XGcA  瑄瑄 & G先生 · 美食夫妻的100次旅行         19
# 4   UCFycVZXj9fRWB_OZfFKe2PA                 欸你這週要幹嘛         22
# 5   UCX2914i1K-kGbgg1ZrLKDSQ             愛玩客 iWalker         19
# 6   UCl3aKvzB7uC5mTlVEWiCogA              ETtoday新聞雲         25
# 7   UC1WBRpr2G-NQvm_-jv-i6gg                    國民大會         25
# 8   UCmArFxfDybtCbo0Fa0Z2xxA                     壹加壹         22
# 9   UCBBaj1tbLxFhHD0bFAa7WPg      presidentialoffice         25
# 10  UCX1HDqVhNUsfQT83atwBiiA               我是馬鈴薯小姐雁靈         19
# 11  UCOQZJC11Gjca5PGeM4-XGcA  瑄瑄 & G先生 · 美食夫妻的100次旅行         22
# 12  UCDCJyLpbfgeVE9iZiEam-Kg               華視新聞 CH52         25
# 13  UCl3aKvzB7uC5mTlVEWiCogA              ETtoday新聞雲         25
# 14  UCJL0SVQt4km_MYwKk_gZ8Fw                   進擊的台灣         25
# 15  UCJL0SVQt4km_MYwKk_gZ8Fw                   進擊的台灣         25
# 16  UCJL0SVQt4km_MYwKk_gZ8Fw                   進擊的台灣         25
# 17  UCYIVkruUoN04UjV9pkBTswg               USTV 非凡電視         25
# 18  UC2M61YK4ntt9iK-23XhDwcw               udn video         25
# 19  UCDCJyLpbfgeVE9iZiEam-Kg               華視新聞 CH52         25
# 20  UCDCJyLpbfgeVE9iZiEam-Kg               華視新聞 CH52         25
# 21  UCrbctXCueK60wHFE2o8YL-Q                 自由時報電子報         24
# 22  UCYIVkruUoN04UjV9pkBTswg               USTV 非凡電視         25
# 23  UCDCJyLpbfgeVE9iZiEam-Kg               華視新聞 CH52         25
# 24  UCO3bfz4KY6zGT5IOaFJuxpA                    中視新聞         25
# 25  UCl3aKvzB7uC5mTlVEWiCogA              ETtoday新聞雲         25
# 26  UCLZBXiS9ZrIXgKBs_SMfGBQ                   少康戰情室         25
# 27  UC6AG81pAkf6Lbi_1VC5NmPA                TBS NEWS         25
# 28  UC2M61YK4ntt9iK-23XhDwcw               udn video         22
# 29  UCDCJyLpbfgeVE9iZiEam-Kg               華視新聞 CH52         25
# 30  UCrbctXCueK60wHFE2o8YL-Q                 自由時報電子報         24
# 31  UCYIVkruUoN04UjV9pkBTswg               USTV 非凡電視         25
# 32  UCDCJyLpbfgeVE9iZiEam-Kg               華視新聞 CH52         25
# 33  UCg8EwsqYmiw7G267xxPyXsg                 NOWnews         25
# 34  UCR3asjvr_WAaxwJYEDV_Bfw               東森新聞 CH51         25
# 35  UC1WBRpr2G-NQvm_-jv-i6gg                    國民大會         25
# 36  UCIU8ha-NHmLjtUwU7dFiXUA               三立新聞網SETN         25
# 37  UCl3aKvzB7uC5mTlVEWiCogA              ETtoday新聞雲         25
# 38  UCrbctXCueK60wHFE2o8YL-Q                 自由時報電子報         24
# 39  UC5nwNW4KdC0SzrhF9BXEYOQ               TVBS NEWS         25
# 40  UCl3aKvzB7uC5mTlVEWiCogA              ETtoday新聞雲         25
# 41  UCO3bfz4KY6zGT5IOaFJuxpA                    中視新聞         25
# 42  UCIU8ha-NHmLjtUwU7dFiXUA               三立新聞網SETN         25
# 43  UCDCJyLpbfgeVE9iZiEam-Kg               華視新聞 CH52         25
# 44  UCPlO3Az7v08IUdl9RuKRUVA               台灣1001個故事         25
# 45  UC83wqqlnYS7Pv_mIaJE1hRw                   非凡大探索         19
# 46  UCl3aKvzB7uC5mTlVEWiCogA              ETtoday新聞雲         25
# 47  UC5l1Yto5oOIgRXlI4p4VKbw                    中天電視         25
# 48  UC8ROUUjHzEQm-ndb69CX8Ww           台視新聞 TTV NEWS         25
# 49  UCp2f7tGJGN6R9Muxipem8Nw                 寰宇新聞 頻道         25
#
#                                                 title      videoId viewCount  \
# 0         ✿沈✿高雄美食 鹽埕大爆吃 小籠包 芒果冰 豆花 金桔豆花 講不完  馬不停蹄吃12家  asoG2IIFClo    243786
# 1                      【千千進食中】高雄鹽埕區！超高評價美食攻略，水水幫你吃起來！  h5Z2U19R2Hs    816536
# 2             傳統早餐店脆蛋餅 高雄熱賣超過半世紀  part2 台灣1001個故事｜白心儀  wy3l6TW-21E     47274
# 3   最美高雄｜6個必去新舊景點 愛上港都魅力 白天玩到黑夜！｜高雄旅遊景點 #高雄 #Beara...  I-stExLbVgY     31349
# 4                          【高雄美食巡禮ep.1】高雄吃到吐！居然挖到大寶店！  Er3Nkc_wTAU   1319941
# 5    【高雄玩夯局】左營不只有車站而已！還有很多古色古香的建築～原來神話故事也在這？！！EP11｜大飛  ZPX9wsltR9w      2094
# 6        小英出手？台積電高雄設廠？ 先進+成熟製程 複製南科經驗｜雲端大富翁 EP7精華【字幕】  lgwoS3G-Zo0      1547
# 7                            高雄市今增9例本土 追蹤疫情 陳其邁說明LIVE  vMCWFJeTOmY     10917
# 8                        經過三年後的高雄變成什麼樣！又有什麼新景點（上）｜壹加壹  3ieSXEQHfAc    231098
# 9                           20210926  總統出席「高雄驛起飛座落儀式」  kLr-8yodEgw      3604
# 10            高雄兩天一夜遊VLOG｜必吃丹丹漢堡、浮誇大碗冰、5元烤鮮蚵！吃貨行程這樣玩~  _CIncOrsStI    139295
# 11   高雄6家超人氣美食 在地人也排隊！9千多則評論的蒸餃？什麼美食高雄才吃得到？還有在地70年老店？  e2rOgOLqj70     18285
# 12                   反惡罷! 高雄鄉親包車赴台中挺陳柏惟｜華視新聞 20211022  o4oif7Q0Ju8      1555
# 13                           大南方崛起！產官青創攜手翻轉高雄　品味港都新風貌  xFvckS1xTMs      1989
# 14          【進擊的台灣 預告】高雄「安全農業」 產地到餐桌 &quot;食&quot;在安心  LI3CYvtv5Xg       395
# 15                         【進擊的高雄】邁邁市長「偷吃」被抓包 口袋美食全曝光  zYty2eGMWWg     32949
# 16                          【進擊的高雄】紐約時報最愛城市 全台唯一高雄市上榜  5Q-MGCf822o    135039
# 17  台積電落腳高雄?高市府喊:水.電.土地已準備好　台積電回應了...│主播賴家瑩｜【錢線快報】...  w6_as9TPMaQ      5416
# 18                                1016蔡英文高雄慰問傷者靈堂安撫家屬  X8PCvgBQd5E      1865
# 19                  高雄商圈夜市券 未納岡山夜市.橋頭老街｜華視新聞 20211013  iYiFAtMgYVg       789
# 20                   城中城惡火奪命 總統指示全力支援高雄｜華視新聞 20211014  jFDstQqUXnA     10549
# 21                         最新》高雄城中城大火釀46死41傷 目擊深入火場調查  m5_2hHHeGII    127961
# 22                                 【完整公開】2021國慶煙火 在高雄  VlePimzwdwo     38578
# 23                  高雄城中城大樓暗夜火 目前2人不幸身亡｜華視新聞 20211014  B1Zg2XKSX44     11781
# 24                         「城中城」屋齡40年　風光到沒落被譏「高雄第一鬼樓」  vGILqc69Sao       737
# 25                      高雄城中城惡火疑情侶吵架丟菸　百人受困蹲鐵窗、揮手電筒求援  v_iNBySe5Nw     45695
# 26    【沈富雄】分析高雄城中城大火 沈富雄:不能有人住!政府強制收購!  少康戰情室20211015  ZDFWuWY5dgE     15482
# 27                                 台湾・高雄でビル火災 死者４０人超か  KokmdS96JeI    168202
# 28                               陳其邁該下台負責？馬英九：由高雄市民決定  jylIRxRNIdE     16700
# 29                   高雄11月大女嬰疑遭虐死 檢方今相驗｜華視新聞 20211018  nFL2b_RGkrE      6539
# 30                          高雄城中城惡火死傷87人 32人明顯死亡直送殯儀館  xLSYIfMC5pQ    149083
# 31  傳台積電進駐高雄五輕舊址...6座新廠助南台灣&quot;半導體S廊道&quot;成形!?｜...  QoKn9CGAwcU      3891
# 32                【完整直擊】110雙十國慶 璀璨煙火在高雄｜華視新聞｜20211010  4MyDIy6asiE     78646
# 33                            P聯盟／高雄鋼鐵人震撼彈！張至言接任球隊總經理  cMFmX1vKQvA      5066
# 34                     又一重大投資！台積電南進高雄建7奈米廠　@東森新聞 CH51  t0CwpIbRnpE     10450
# 35  高雄城中城大火 網友凌晨3點PO&quot;爆料文&quot;成線索! 警消列重要證據 國民...  srRem32QCME     28079
# 36            「高雄城中城」起火畫面曝光！男出現19秒後冒亮光｜三立新聞網 SETN.com  psjw0N-zBE8     78947
# 37                         高雄城中城大火24死！消防局長再曝：會超過40人命危  VC9-zvJM7a8     73278
# 38                   國慶煙火試放三分鐘 270發展現高雄百年大港氣勢(高雄市府提供)  nHusOU2qY2Q     31049
# 39                      睽違21年!國慶焰火高雄登場 2萬發璀璨夜空｜TVBS新聞  yH5WoJge8OY     28933
# 40   【LIVE】5/19 針對「仁惠醫院」染疫相關篩檢 高雄市府防疫記者會說明 ＃陳其邁 ＃台灣疫情  d4KnqVyEjRA     11859
# 41  高雄&quot;城中城&quot;惡火46死 起火瞬間&quot;1分鐘&quot;延燒│中...  6ZWhTqiHx70       821
# 42       高雄城中城大火困百人！她從台南連夜趕回仰天跪地：爸媽沒出來｜三立新聞網 SETN.com  Q5lO-0rxZJk     27318
# 43                     高雄城中城凌晨惡火 百人受困慘叫｜華視新聞 20211014  14ks5QDt7rk     45704
# 44  【台灣1001個故事 精選】高雄內行才知道超限量梅子雞    皮酥肉嫩多汁火燒雞｜白心儀 T...  0_qLTJMbBrs     41246
# 45  高雄&quot;生猛海鮮吃到飽&quot; - 大胃王天堂吃到飽│高雄美食必吃│野饌燒肉火烤...  H78IJ_RNxuA     85992
# 46    台積南科經驗   高雄能複製貼上？ 來賓曝下一個翻轉城市在這！｜雲端大富翁 EP8精華【字幕】  nyAmP1jWyA8       348
# 47  【BOSS工作室 BO快訊】高雄暗夜爆炸火警 鹽埕區城中城大樓救出41多人受傷46亡 @中天...  ugQPsHU0phM     30049
# 48                              高雄國慶煙火交通管制曝! 會場將不提供車位  ijYKgwsnRFE      6185
# 49   高鐵輕軌進行初勘 演練隨機砍人案應變 #高雄 #鼓山站 #陳其邁 #台鐵轉乘站 @寰宇新聞 頻道  fcu5Ok2nnwM       449
#
#    likeCount dislikeCount commentCount favoriteCount
# 0       3308          127          465             0
# 1      11721          378         1436             0
# 2        283            7           22             0
# 3        418           17           52             0
# 4      15924          421         1149             0
# 5         28            3            0             0
# 6         14            1            1             0
# 7        270           36           41             0
# 8       6172           71          332             0
# 9        241            7           23             0
# 10      2123           50          312             0
# 11       250           13           33             0
# 12        35           25           27             0
# 13        51            2           11             0
# 14        10            0            0             0
# 15       170           46           18             0
# 16      2136          193          408             0
# 17        48            2            4             0
# 18        11           28           12             0
# 19         7            0            0             0
# 20        41           19           58             0
# 21       436          168          699             0
# 22       248           46           13             0
# 23        43           11           37             0
# 24         6            0            2             0
# 25       176           33          527             0
# 26       149           10           62             0
# 27       434           47          238             0
# 28       130           53          203             0
# 29        22            1            9             0
# 30       412          173          605             0
# 31        45            2            9             0
# 32      1037           67          129             0
# 33        22            4            5             0
# 34        94            5           36             0
# 35      1170           22          169             0
# 36       240          209          348             0
# 37       234           44          321             0
# 38       269           22           49             0
# 39       219           49          128             0
# 40        53            5           11             0
# 41         5            0            7             0
# 42        84           32          112             0
# 43       158           40          226             0
# 44       249           21           23             0
# 45       422           21           41             0
# 46         2            0            1             0
# 47       615           15          116             0
# 48        34            1            9             0
# 49         4            0            1             0
